# %%
import heapq
from collections import deque
import random

# %%
class ColaPrioridadLimitada(object):
    def __init__(self, limite=None, *args):
        self.limite = limite
        self.queue = list()

    def __getitem__(self, val):
        return self.queue[val]

    def __len__(self):
        return len(self.queue)

    def push(self, x):
        heapq.heappush(self.queue, x)
        if self.limite and len(self.queue) > self.limite:
            self.queue.remove(heapq.nlargest(1, self.queue)[0])

    def pop(self):
        return heapq.heappop(self.queue)

    def extend(self, iterable):
        for x in iterable:
            self.append(x)

    def clear(self):
        for x in self:
            self.queue.remove(x)

    def remove(self, x):
        self.queue.remove(x)

    # Metodo para saber si la cola esta vacia
    def empty(self):
        if not self.heap:
            return True
        else:
            return False
        
    def sorted(self):
        return heapq.nsmallest(len(self.queue), self.queue)

# %%
class NodoBusqueda(object):
    '''Nodo para el proceso de busqueda.'''

    def __init__(self, estado, padre=None, accion=None, costo=0, problema=None, profundidad=0):
        self.estado = estado
        self.padre = padre
        self.accion = accion
        self.costo = costo
        self.problema = problema or padre.problema
        self.profundidad = profundidad

    def expandir(self, busqueda_local=False):
        '''Crear sucesores.'''
        nodos_nuevos = []
        for accion in self.problema.acciones(self.estado):
            estado_nuevo = self.problema.resultado(self.estado, accion)
            costo = self.problema.costo(self.estado, accion, estado_nuevo)
            fabrica_nodos = self.__class__
            nodos_nuevos.append(fabrica_nodos(estado=estado_nuevo,
                                         padre=None if busqueda_local else self,
                                         problema=self.problema,
                                         accion=accion,
                                         costo=self.costo + costo,
                                         profundidad=self.profundidad + 1))
        return nodos_nuevos

    def camino(self):
        '''Camino (lista de nodos y acciones) desde el nodo raiz al nodo actual.'''
        nodo = self
        camino = []
        while nodo:
            camino.append((nodo.accion, nodo.estado))
            nodo = nodo.padre
        return list(reversed(camino))

    def __eq__(self, otro):
        return isinstance(otro, NodoBusqueda) and self.estado == otro.estado

    def estado_representacion(self):
        return self.problema.estado_representacion(self.estado)

    def accion_representacion(self):
        return self.problema.accion_representacion(self.accion)

    def __repr__(self):
        return 'Node <%s>' % self.estado_representacion().replace('\n', ' ')

    def __hash__(self):
        return hash((
            self.estado,
            self.padre,
            self.accion,
            self.costo,
            self.profundidad,
        ))

# %%
class NodoBusquedaHeuristicaOrdenado(NodoBusqueda):
    def __init__(self, *args, **kwargs):
        super(NodoBusquedaHeuristicaOrdenado, self).__init__(*args, **kwargs)
        self.heuristica = self.problema.heuristica(self.estado)

    def __lt__(self, otro):
        return self.heuristica < otro.heuristica

# %%
class NodoBusquedaAEstrellaOrdenado(NodoBusquedaHeuristicaOrdenado):
    def __lt__(self, otro):
        return self.heuristica + self.costo < otro.heuristica + otro.costo

# %%
class ProblemaBusqueda(object):
    '''Clase base abstracta, para representar y manipular los espacio de busqueda
    de un problema. IEn esta clase, el espacio de búsqueda debe representarse 
    implícitamente como un gráfico.
    Cada estado corresponde con un estado del problema(es decir, una configuración válida) 
    y cada accion del problema(es decir, una transformación válida a una configuración) corresponde con un limite o frontera.
    Para utilizar esta clase se debe implementar metodos requeridos by el algoritmo de busqueda
    que se utilizara.'''

    def __init__(self, estado_inicial=None):
        self.estado_inicial = estado_inicial

    def acciones(self, estado):
        '''Devuelve las acciones disponibles para realizar a partir de un estado.
        El valor devuelto es íterador sobre acciones.
        Las acciones son específicas del problema y no se debe asumir nada sobre ellas.
        '''
        raise NotImplementedError

    def resultado(self, estado, accion):
        '''Debuelve un nuevo estado despues de aplicar una accion a estado.'''
        raise NotImplementedError

    def costo(self, estado, accion, estado2):
        '''Devuelve el costo de aplicar una accion para alcanzar el estado2 a partir de estado.
            El valor devuelto es un numero (intero o de punto flotante),
            por defecto la funcion devuelve 1.
        '''
        return 1

    def es_objetivo(self, estado):
        '''Devuelve True si estado es el estado_objetivo y false caso contrario'''
        raise NotImplementedError

    def valor(self, estado):
        '''Devuelve el valor de `estado`, para motivos de optimizacion.
           valor es un numero (entero o punto flotante).'''
        raise NotImplementedError

    def heuristica(self, estado):
        '''DEvuelve un estimado del costo faltante para alcanzar la solucion a partir de `estado`.'''
        return 0

    def estado_representacion(self, estado):
        """
        Devuelve un string de representacion de un estado.
        Por defecto devuelve str(estado).
        """
        return str(estado)

    def accion_representacion(self, accion):
        """
        Devuelve un string de representacion de una acción.
        Por defecto devuelve str(acción).
        """
        return str(accion)

# %%
def aestrella(problema, busqueda_en_grafo=False, viewer=None):
    '''
    Busuqeda A*.

    Si se establece busqueda_en_grafo=True, se eliminara la busqueda en estados repetidos.
    Requiere redefinir las funciones de la clase ProblemaBusqueda:
    ProblemaBusqueda.acciones, ProblemaBusqueda.resultado, y
    ProblemaBusqueda.es_objetivo, ProblemaBusqueda.costo,
    ProblemaBusqueda.heuristica.
    '''
    return _buscar(problema,
                   ColaPrioridadLimitada(),
                   busqueda_en_grafo=busqueda_en_grafo,
                   fabrica_nodos=NodoBusquedaAEstrellaOrdenado,
                   reemplazar_grafo_cuando_mejor=True)

# %%
def _buscar(problema, frontera, busqueda_en_grafo=False, limite_profundidad=None,
            fabrica_nodos=NodoBusqueda, reemplazar_grafo_cuando_mejor=False):
    '''
    Algoritmo basico de busqueda, base de todos los demas algoritmos de busqueda.
    '''
    memoria = set()
    nodo_inicio = fabrica_nodos(estado=problema.estado_inicial, problema=problema)
    print("el nodod incio es:",nodo_inicio)
    frontera.push(nodo_inicio)
    
    while frontera:
        nodo = frontera.pop()
        print(nodo)

        if problema.es_objetivo(nodo.estado):
            print(nodo.estado)
            return nodo
    
        memoria.add(nodo.estado)
        print(len(memoria))

        if limite_profundidad is None or nodo.profundidad < limite_profundidad:
            expandido = nodo.expandir()
            print("El expadido es:",expandido)
    
            for n in expandido:
                if busqueda_en_grafo:
                    otros = [x for x in frontera if x.estado == n.estado]
                    print("valores de otros:",otros)
                    assert len(otros) in (0, 1)
                    if n.estado not in memoria and len(otros) == 0:
                        frontera.push(n)
                    elif reemplazar_grafo_cuando_mejor and len(otros) > 0 and n < otros[0]:
                        frontera.remove(otros[0])
                        frontera.push(n)
                else:
                    frontera.push(n)

# %%
import math
class EigthPuzzleProblem(ProblemaBusqueda):
    def acciones(self, estado):
        '''Devuelve una lista de piesas que se pueden mover a un espacio vacio.'''
        filas = string_to_list(estado)
        print("filas:",filas,)
        fila_e, columna_e = find_location(filas, 'e')
        print(fila_e)
        print(columna_e)

        acciones = []
        if fila_e > 0:
            acciones.append(filas[fila_e - 1][columna_e])
        if fila_e < 2:
            acciones.append(filas[fila_e + 1][columna_e])
        if columna_e > 0:
            acciones.append(filas[fila_e][columna_e - 1])
        if columna_e < 1:
            acciones.append(filas[fila_e][columna_e + 1])

        print("las acciones",acciones)

        return acciones

    def resultado(self, estado, accion):
        '''Devuelve el resultado despues de mover una pieza a un espacio en vacio
        '''
        filas = string_to_list(estado)
        fila_e, columna_e = find_location(filas, 'e')
        fila_n, columna_n = find_location(filas, accion)
        print(fila_e)
        print(columna_e)
        print(fila_n)
        print(columna_n)


        filas[fila_e][columna_e], filas[fila_n][columna_n] = filas[fila_n][columna_n], filas[fila_e][columna_e]
        print("   ",filas)
        result=list_to_string(filas)
        print("resulte",result)
        #print("{} estados visitados en total (frontera y explorados)".format(len(frontera)+len(explorado)))
        return list_to_string(filas)

    def es_objetivo(self, estado):
        '''Devuelve True si un estado es el estado_objetivo.'''
        return estado == OBJETIVO

    def costo(self, estado1, accion, estado2):
        '''Devuelve el costo de ejecutar una accion. 
        '''
        return 1

    def heuristica(self, estado):
#         Devuelve una estimacion de la distancia de un estado a otro, utilizando la distancia manhattan.
        filas = string_to_list(estado)
        print("Las filas son:",filas)

        distancia = 0

        for numero in '12345e':
            fila_n, columna_n = find_location(filas, numero)
            fila_n_objetivo, col_n_goal = posiciones_objetivo[numero]

            distancia += abs(fila_n - fila_n_objetivo) + abs(columna_n - col_n_goal)
            print("las dintancias",distancia)

        return distancia

    #def heuristic(self, estado):
     #   x, y = estado
      #  gx, gy = self.estado_objetivo
       # return math.sqrt((x - gx) ** 2 + (y - gy) ** 2)


      # no muestra la solucion por falta de memoria ram funciona con : 2,e,3,5,4,1
      # 2,e,4,3,5,1
      # e,2,4,1,3,5
      # 3,2,4,1,e,5
      # 3,2,4,5,e,1
      # 1,2,4,e,5,3
      #funciona: 4,e,3,5,2,1
      #2,e,4,5,3,1
      #e,5,4,3,2,1
      #2,e,4,3,1,5
      #1,2,4,5,e,3
      #5,4,3,2,1,e
      #2,4,3,1,5,e

# %%
OBJETIVO = '''1-2
3-4
5-e'''

INICIAL = '''2-e
4-5
3-1'''

def list_to_string(list_):
    return '\n'.join(['-'.join(row) for row in list_])

def string_to_list(string_):
    return [row.split('-') for row in string_.split('\n')]

def find_location(filas, element_to_find):
    '''Encuentra la ubicacion de una pieza (la pieza vacia) en el rompecabezas.
       DEvuelve una tupla: fila, columna'''
    for ir, row in enumerate(filas):
        for ic, element in enumerate(row):
            if element == element_to_find:
                return ir, ic

posiciones_objetivo = {}
filas_objetivo = string_to_list(OBJETIVO)
for numero in '12345e':
    posiciones_objetivo[numero] = find_location(filas_objetivo, numero)
problema = EigthPuzzleProblem(INICIAL)
resultado = aestrella(problema)
print(resultado)

for accion, estado in resultado.camino():
    print('Mueve el numero', accion)
    print(estado)
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
# las dintancias 3
# las dintancias 3
# las dintancias 4
# las dintancias 7
# las dintancias 8
# 2
# 1
# 2
# 0
#     [['2', '5'], ['3', '4'], ['e', '1']]
# resulte 2-5
# 3-4
# e-1
# Las filas son: [['2', '5'], ['3', '4'], ['e', '1']]
# las dintancias 3
# las dintancias 4
# las dintancias 4
# las dintancias 4
# las dintancias 7
# las dintancias 8
# El expadido es: [Node <2-5 3-e 1-4>, Node <2-5 3-4 e-1>]
# Node <4-2 3-e 1-5>
# 69
# filas: [['4', '2'], ['3', 'e'], ['1', '5']]
# 1
# 1
# las acciones ['2', '5', '3']
# 1
# 1
# 0
# 1
#     [['4', 'e'], ['3', '2'], ['1', '5']]
# resulte 4-e
# 3-2
# 1-5
# Las filas son: [['4', 'e'], ['3', '2'], ['1', '5']]
# las dintancias 2
# las dintancias 3
# las dintancias 3
# las dintancias 5
# las dintancias 6
# las dintancias 8
# 1
# 1
# 2
# 1
#     [['4', '2'], ['3', '5'], ['1', 'e']]
# resulte 4-2
# 3-5
# 1-e
# Las filas son: [['4', '2'], ['3', '5'], ['1', 'e']]
# las dintancias 2
# las dintancias 2
# las dintancias 2
# las dintancias 4
# las dintancias 6
# las dintancias 6
# 1
# 1
# 1
# 0
#     [['4', '2'], ['e', '3'], ['1', '5']]
# resulte 4-2
# e-3
# 1-5
# Las filas son: [['4', '2'], ['e', '3'], ['1', '5']]
# las dintancias 2
# las dintancias 2
# las dintancias 3
# las dintancias 5
# las dintancias 6
# las dintancias 8
# El expadido es: [Node <4-e 3-2 1-5>, Node <4-2 3-5 1-e>, Node <4-2 e-3 1-5>]
# Node <2-1 5-4 e-3>
# 70
# filas: [['2', '1'], ['5', '4'], ['e', '3']]
# 2
# 0
# las acciones ['5', '3']
# 2
# 0
# 1
# 0
#     [['2', '1'], ['e', '4'], ['5', '3']]
# resulte 2-1
# e-4
# 5-3
# Las filas son: [['2', '1'], ['e', '4'], ['5', '3']]
# las dintancias 1
# las dintancias 2
# las dintancias 4
# las dintancias 4
# las dintancias 4
# las dintancias 6
# 2
# 0
# 2
# 1
#     [['2', '1'], ['5', '4'], ['3', 'e']]
# resulte 2-1
# 5-4
# 3-e
# Las filas son: [['2', '1'], ['5', '4'], ['3', 'e']]
# las dintancias 1
# las dintancias 2
# las dintancias 3
# las dintancias 3
# las dintancias 4
# las dintancias 4
# El expadido es: [Node <2-1 e-4 5-3>, Node <2-1 5-4 3-e>]
# Node <2-1 5-4 3-e>
# 71
# filas: [['2', '1'], ['5', '4'], ['3', 'e']]
# 2
# 1
# las acciones ['4', '3']
# 2
# 1
# 1
# 1
#     [['2', '1'], ['5', 'e'], ['3', '4']]
# resulte 2-1
# 5-e
# 3-4
# Las filas son: [['2', '1'], ['5', 'e'], ['3', '4']]
# las dintancias 1
# las dintancias 2
# las dintancias 3
# las dintancias 4
# las dintancias 5
# las dintancias 6
# 2
# 1
# 2
# 0
#     [['2', '1'], ['5', '4'], ['e', '3']]
# resulte 2-1
# 5-4
# e-3
# Las filas son: [['2', '1'], ['5', '4'], ['e', '3']]
# las dintancias 1
# las dintancias 2
# las dintancias 4
# las dintancias 4
# las dintancias 5
# las dintancias 6
# El expadido es: [Node <2-1 5-e 3-4>, Node <2-1 5-4 e-3>]
# Node <4-2 5-1 e-3>
# 71
# filas: [['4', '2'], ['5', '1'], ['e', '3']]
# 2
# 0
# las acciones ['5', '3']
# 2
# 0
# 1
# 0
#     [['4', '2'], ['e', '1'], ['5', '3']]
# resulte 4-2
# e-1
# 5-3
# Las filas son: [['4', '2'], ['e', '1'], ['5', '3']]
# las dintancias 2
# las dintancias 2
# las dintancias 4
# las dintancias 6
# las dintancias 6
# las dintancias 8
# 2
# 0
# 2
# 1
#     [['4', '2'], ['5', '1'], ['3', 'e']]
# resulte 4-2
# 5-1
# 3-e
# Las filas son: [['4', '2'], ['5', '1'], ['3', 'e']]
# las dintancias 2
# las dintancias 2
# las dintancias 3
# las dintancias 5
# las dintancias 6
# las dintancias 6
# El expadido es: [Node <4-2 e-1 5-3>, Node <4-2 5-1 3-e>]
# Node <4-2 5-1 3-e>
# 71
# filas: [['4', '2'], ['5', '1'], ['3', 'e']]
# 2
# 1
# las acciones ['1', '3']
# 2
# 1
# 1
# 1
#     [['4', '2'], ['5', 'e'], ['3', '1']]
# resulte 4-2
# 5-e
# 3-1
# Las filas son: [['4', '2'], ['5', 'e'], ['3', '1']]
# las dintancias 3
# las dintancias 3
# las dintancias 4
# las dintancias 6
# las dintancias 7
# las dintancias 8
# 2
# 1
# 2
# 0
#     [['4', '2'], ['5', '1'], ['e', '3']]
# resulte 4-2
# 5-1
# e-3
# Las filas son: [['4', '2'], ['5', '1'], ['e', '3']]
# las dintancias 2
# las dintancias 2
# las dintancias 4
# las dintancias 6
# las dintancias 7
# las dintancias 8
# El expadido es: [Node <4-2 5-e 3-1>, Node <4-2 5-1 e-3>]
# Node <4-2 1-3 e-5>
# 71
# filas: [['4', '2'], ['1', '3'], ['e', '5']]
# 2
# 0
# las acciones ['1', '5']
# 2
# 0
# 1
# 0
#     [['4', '2'], ['e', '3'], ['1', '5']]
# resulte 4-2
# e-3
# 1-5
# Las filas son: [['4', '2'], ['e', '3'], ['1', '5']]
# las dintancias 2
# las dintancias 2
# las dintancias 3
# las dintancias 5
# las dintancias 6
# las dintancias 8
# 2
# 0
# 2
# 1
#     [['4', '2'], ['1', '3'], ['5', 'e']]
# resulte 4-2
# 1-3
# 5-e
# Las filas son: [['4', '2'], ['1', '3'], ['5', 'e']]
# las dintancias 1
# las dintancias 1
# las dintancias 2
# las dintancias 4
# las dintancias 4
# las dintancias 4
# El expadido es: [Node <4-2 e-3 1-5>, Node <4-2 1-3 5-e>]
# Node <4-2 1-3 5-e>
# 71
# filas: [['4', '2'], ['1', '3'], ['5', 'e']]
# 2
# 1
# las acciones ['3', '5']
# 2
# 1
# 1
# 1
#     [['4', '2'], ['1', 'e'], ['5', '3']]
# resulte 4-2
# 1-e
# 5-3
# Las filas son: [['4', '2'], ['1', 'e'], ['5', '3']]
# las dintancias 1
# las dintancias 1
# las dintancias 3
# las dintancias 5
# las dintancias 5
# las dintancias 6
# 2
# 1
# 2
# 0
#     [['4', '2'], ['1', '3'], ['e', '5']]
# resulte 4-2
# 1-3
# e-5
# Las filas son: [['4', '2'], ['1', '3'], ['e', '5']]
# las dintancias 1
# las dintancias 1
# las dintancias 2
# las dintancias 4
# las dintancias 5
# las dintancias 6
# El expadido es: [Node <4-2 1-e 5-3>, Node <4-2 1-3 e-5>]
# Node <4-2 5-1 e-3>
# 71
# filas: [['4', '2'], ['5', '1'], ['e', '3']]
# 2
# 0
# las acciones ['5', '3']
# 2
# 0
# 1
# 0
#     [['4', '2'], ['e', '1'], ['5', '3']]
# resulte 4-2
# e-1
# 5-3
# Las filas son: [['4', '2'], ['e', '1'], ['5', '3']]
# las dintancias 2
# las dintancias 2
# las dintancias 4
# las dintancias 6
# las dintancias 6
# las dintancias 8
# 2
# 0
# 2
# 1
#     [['4', '2'], ['5', '1'], ['3', 'e']]
# resulte 4-2
# 5-1
# 3-e
# Las filas son: [['4', '2'], ['5', '1'], ['3', 'e']]
# las dintancias 2
# las dintancias 2
# las dintancias 3
# las dintancias 5
# las dintancias 6
# las dintancias 6
# El expadido es: [Node <4-2 e-1 5-3>, Node <4-2 5-1 3-e>]
# Node <4-2 5-1 3-e>
# 71
# filas: [['4', '2'], ['5', '1'], ['3', 'e']]
# 2
# 1
# las acciones ['1', '3']
# 2
# 1
# 1
# 1
#     [['4', '2'], ['5', 'e'], ['3', '1']]
# resulte 4-2
# 5-e
# 3-1
# Las filas son: [['4', '2'], ['5', 'e'], ['3', '1']]
# las dintancias 3
# las dintancias 3
# las dintancias 4
# las dintancias 6
# las dintancias 7
# las dintancias 8
# 2
# 1
# 2
# 0
#     [['4', '2'], ['5', '1'], ['e', '3']]
# resulte 4-2
# 5-1
# e-3
# Las filas son: [['4', '2'], ['5', '1'], ['e', '3']]
# las dintancias 2
# las dintancias 2
# las dintancias 4
# las dintancias 6
# las dintancias 7
# las dintancias 8
# El expadido es: [Node <4-2 5-e 3-1>, Node <4-2 5-1 e-3>]
# Node <4-2 5-1 e-3>
# 71
# filas: [['4', '2'], ['5', '1'], ['e', '3']]
# 2
# 0
# las acciones ['5', '3']
# 2
# 0
# 1
# 0
#     [['4', '2'], ['e', '1'], ['5', '3']]
# resulte 4-2
# e-1
# 5-3
# Las filas son: [['4', '2'], ['e', '1'], ['5', '3']]
# las dintancias 2
# las dintancias 2
# las dintancias 4
# las dintancias 6
# las dintancias 6
# las dintancias 8
# 2
# 0
# 2
# 1
#     [['4', '2'], ['5', '1'], ['3', 'e']]
# resulte 4-2
# 5-1
# 3-e
# Las filas son: [['4', '2'], ['5', '1'], ['3', 'e']]
# las dintancias 2
# las dintancias 2
# las dintancias 3
# las dintancias 5
# las dintancias 6
# las dintancias 6
# El expadido es: [Node <4-2 e-1 5-3>, Node <4-2 5-1 3-e>]
# Node <4-2 5-1 3-e>
# 71
# filas: [['4', '2'], ['5', '1'], ['3', 'e']]
# 2
# 1
# las acciones ['1', '3']
# 2
# 1
# 1
# 1
#     [['4', '2'], ['5', 'e'], ['3', '1']]
# resulte 4-2
# 5-e
# 3-1
# Las filas son: [['4', '2'], ['5', 'e'], ['3', '1']]
# las dintancias 3
# las dintancias 3
# las dintancias 4
# las dintancias 6
# las dintancias 7
# las dintancias 8
# 2
# 1
# 2
# 0
#     [['4', '2'], ['5', '1'], ['e', '3']]
# resulte 4-2
# 5-1
# e-3
# Las filas son: [['4', '2'], ['5', '1'], ['e', '3']]
# las dintancias 2
# las dintancias 2
# las dintancias 4
# las dintancias 6
# las dintancias 7
# las dintancias 8
# El expadido es: [Node <4-2 5-e 3-1>, Node <4-2 5-1 e-3>]
# Node <4-2 3-e 1-5>
# 71
# filas: [['4', '2'], ['3', 'e'], ['1', '5']]
# 1
# 1
# las acciones ['2', '5', '3']
# 1
# 1
# 0
# 1
#     [['4', 'e'], ['3', '2'], ['1', '5']]
# resulte 4-e
# 3-2
# 1-5
# Las filas son: [['4', 'e'], ['3', '2'], ['1', '5']]
# las dintancias 2
# las dintancias 3
# las dintancias 3
# las dintancias 5
# las dintancias 6
# las dintancias 8
# 1
# 1
# 2
# 1
#     [['4', '2'], ['3', '5'], ['1', 'e']]
# resulte 4-2
# 3-5
# 1-e
# Las filas son: [['4', '2'], ['3', '5'], ['1', 'e']]
# las dintancias 2
# las dintancias 2
# las dintancias 2
# las dintancias 4
# las dintancias 6
# las dintancias 6
# 1
# 1
# 1
# 0
#     [['4', '2'], ['e', '3'], ['1', '5']]
# resulte 4-2
# e-3
# 1-5
# Las filas son: [['4', '2'], ['e', '3'], ['1', '5']]
# las dintancias 2
# las dintancias 2
# las dintancias 3
# las dintancias 5
# las dintancias 6
# las dintancias 8
# El expadido es: [Node <4-e 3-2 1-5>, Node <4-2 3-5 1-e>, Node <4-2 e-3 1-5>]
# Node <2-5 3-4 e-1>
# 71
# filas: [['2', '5'], ['3', '4'], ['e', '1']]
# 2
# 0
# las acciones ['3', '1']
# 2
# 0
# 1
# 0
#     [['2', '5'], ['e', '4'], ['3', '1']]
# resulte 2-5
# e-4
# 3-1
# Las filas son: [['2', '5'], ['e', '4'], ['3', '1']]
# las dintancias 3
# las dintancias 4
# las dintancias 5
# las dintancias 5
# las dintancias 8
# las dintancias 10
# 2
# 0
# 2
# 1
#     [['2', '5'], ['3', '4'], ['1', 'e']]
# resulte 2-5
# 3-4
# 1-e
# Las filas son: [['2', '5'], ['3', '4'], ['1', 'e']]
# las dintancias 2
# las dintancias 3
# las dintancias 3
# las dintancias 3
# las dintancias 6
# las dintancias 6
# El expadido es: [Node <2-5 e-4 3-1>, Node <2-5 3-4 1-e>]
# Node <2-5 3-4 1-e>
# 71
# filas: [['2', '5'], ['3', '4'], ['1', 'e']]
# 2
# 1
# las acciones ['4', '1']
# 2
# 1
# 1
# 1
#     [['2', '5'], ['3', 'e'], ['1', '4']]
# resulte 2-5
# 3-e
# 1-4
# Las filas son: [['2', '5'], ['3', 'e'], ['1', '4']]
# las dintancias 2
# las dintancias 3
# las dintancias 3
# las dintancias 4
# las dintancias 7
# las dintancias 8
# 2
# 1
# 2
# 0
#     [['2', '5'], ['3', '4'], ['e', '1']]
# resulte 2-5
# 3-4
# e-1
# Las filas son: [['2', '5'], ['3', '4'], ['e', '1']]
# las dintancias 3
# las dintancias 4
# las dintancias 4
# las dintancias 4
# las dintancias 7
# las dintancias 8
# El expadido es: [Node <2-5 3-e 1-4>, Node <2-5 3-4 e-1>]
# Node <5-4 2-e 3-1>
# 71
# filas: [['5', '4'], ['2', 'e'], ['3', '1']]
# 1
# 1
# las acciones ['4', '1', '2']
# 1
# 1
# 0
# 1
#     [['5', 'e'], ['2', '4'], ['3', '1']]
# resulte 5-e
# 2-4
# 3-1
# Las filas son: [['5', 'e'], ['2', '4'], ['3', '1']]
# las dintancias 3
# las dintancias 5
# las dintancias 6
# las dintancias 6
# las dintancias 8
# las dintancias 10
# 1
# 1
# 2
# 1
#     [['5', '4'], ['2', '1'], ['3', 'e']]
# resulte 5-4
# 2-1
# 3-e
# Las filas son: [['5', '4'], ['2', '1'], ['3', 'e']]
# las dintancias 2
# las dintancias 4
# las dintancias 5
# las dintancias 6
# las dintancias 8
# las dintancias 8
# 1
# 1
# 1
# 0
#     [['5', '4'], ['e', '2'], ['3', '1']]
# resulte 5-4
# e-2
# 3-1
# Las filas son: [['5', '4'], ['e', '2'], ['3', '1']]
# las dintancias 3
# las dintancias 4
# las dintancias 5
# las dintancias 6
# las dintancias 8
# las dintancias 10
# El expadido es: [Node <5-e 2-4 3-1>, Node <5-4 2-1 3-e>, Node <5-4 e-2 3-1>]
# Node <5-4 2-1 3-e>
# 71
# filas: [['5', '4'], ['2', '1'], ['3', 'e']]
# 2
# 1
# las acciones ['1', '3']
# 2
# 1
# 1
# 1
#     [['5', '4'], ['2', 'e'], ['3', '1']]
# resulte 5-4
# 2-e
# 3-1
# Las filas son: [['5', '4'], ['2', 'e'], ['3', '1']]
# las dintancias 3
# las dintancias 5
# las dintancias 6
# las dintancias 7
# las dintancias 9
# las dintancias 10
# 2
# 1
# 2
# 0
#     [['5', '4'], ['2', '1'], ['e', '3']]
# resulte 5-4
# 2-1
# e-3
# Las filas son: [['5', '4'], ['2', '1'], ['e', '3']]
# las dintancias 2
# las dintancias 4
# las dintancias 6
# las dintancias 7
# las dintancias 9
# las dintancias 10
# El expadido es: [Node <5-4 2-e 3-1>, Node <5-4 2-1 e-3>]
# Node <e-4 5-2 3-1>
# 71
# filas: [['e', '4'], ['5', '2'], ['3', '1']]
# 0
# 0
# las acciones ['5', '4']
# 0
# 0
# 1
# 0
#     [['5', '4'], ['e', '2'], ['3', '1']]
# resulte 5-4
# e-2
# 3-1
# Las filas son: [['5', '4'], ['e', '2'], ['3', '1']]
# las dintancias 3
# las dintancias 4
# las dintancias 5
# las dintancias 6
# las dintancias 8
# las dintancias 10
# 0
# 0
# 0
# 1
#     [['4', 'e'], ['5', '2'], ['3', '1']]
# resulte 4-e
# 5-2
# 3-1
# Las filas son: [['4', 'e'], ['5', '2'], ['3', '1']]
# las dintancias 3
# las dintancias 4
# las dintancias 5
# las dintancias 7
# las dintancias 8
# las dintancias 10
# El expadido es: [Node <5-4 e-2 3-1>, Node <4-e 5-2 3-1>]
# Node <2-5 3-4 e-1>
# 71
# filas: [['2', '5'], ['3', '4'], ['e', '1']]
# 2
# 0
# las acciones ['3', '1']
# 2
# 0
# 1
# 0
#     [['2', '5'], ['e', '4'], ['3', '1']]
# resulte 2-5
# e-4
# 3-1
# Las filas son: [['2', '5'], ['e', '4'], ['3', '1']]
# las dintancias 3
# las dintancias 4
# las dintancias 5
# las dintancias 5
# las dintancias 8
# las dintancias 10
# 2
# 0
# 2
# 1
#     [['2', '5'], ['3', '4'], ['1', 'e']]
# resulte 2-5
# 3-4
# 1-e
# Las filas son: [['2', '5'], ['3', '4'], ['1', 'e']]
# las dintancias 2
# las dintancias 3
# las dintancias 3
# las dintancias 3
# las dintancias 6
# las dintancias 6
# El expadido es: [Node <2-5 e-4 3-1>, Node <2-5 3-4 1-e>]
# Node <2-5 3-4 1-e>
# 71
# filas: [['2', '5'], ['3', '4'], ['1', 'e']]
# 2
# 1
# las acciones ['4', '1']
# 2
# 1
# 1
# 1
#     [['2', '5'], ['3', 'e'], ['1', '4']]
# resulte 2-5
# 3-e
# 1-4
# Las filas son: [['2', '5'], ['3', 'e'], ['1', '4']]
# las dintancias 2
# las dintancias 3
# las dintancias 3
# las dintancias 4
# las dintancias 7
# las dintancias 8
# 2
# 1
# 2
# 0
#     [['2', '5'], ['3', '4'], ['e', '1']]
# resulte 2-5
# 3-4
# e-1
# Las filas son: [['2', '5'], ['3', '4'], ['e', '1']]
# las dintancias 3
# las dintancias 4
# las dintancias 4
# las dintancias 4
# las dintancias 7
# las dintancias 8
# El expadido es: [Node <2-5 3-e 1-4>, Node <2-5 3-4 e-1>]
# Node <2-5 3-e 1-4>
# 71
# filas: [['2', '5'], ['3', 'e'], ['1', '4']]
# 1
# 1
# las acciones ['5', '4', '3']
# 1
# 1
# 0
# 1
#     [['2', 'e'], ['3', '5'], ['1', '4']]
# resulte 2-e
# 3-5
# 1-4
# Las filas son: [['2', 'e'], ['3', '5'], ['1', '4']]
# las dintancias 2
# las dintancias 3
# las dintancias 3
# las dintancias 4
# las dintancias 6
# las dintancias 8
# 1
# 1
# 2
# 1
#     [['2', '5'], ['3', '4'], ['1', 'e']]
# resulte 2-5
# 3-4
# 1-e
# Las filas son: [['2', '5'], ['3', '4'], ['1', 'e']]
# las dintancias 2
# las dintancias 3
# las dintancias 3
# las dintancias 3
# las dintancias 6
# las dintancias 6
# 1
# 1
# 1
# 0
#     [['2', '5'], ['e', '3'], ['1', '4']]
# resulte 2-5
# e-3
# 1-4
# Las filas son: [['2', '5'], ['e', '3'], ['1', '4']]
# las dintancias 2
# las dintancias 3
# las dintancias 4
# las dintancias 5
# las dintancias 8
# las dintancias 10
# El expadido es: [Node <2-e 3-5 1-4>, Node <2-5 3-4 1-e>, Node <2-5 e-3 1-4>]
# Node <2-5 3-4 1-e>
# 71
# filas: [['2', '5'], ['3', '4'], ['1', 'e']]
# 2
# 1
# las acciones ['4', '1']
# 2
# 1
# 1
# 1
#     [['2', '5'], ['3', 'e'], ['1', '4']]
# resulte 2-5
# 3-e
# 1-4
# Las filas son: [['2', '5'], ['3', 'e'], ['1', '4']]
# las dintancias 2
# las dintancias 3
# las dintancias 3
# las dintancias 4
# las dintancias 7
# las dintancias 8
# 2
# 1
# 2
# 0
#     [['2', '5'], ['3', '4'], ['e', '1']]
# resulte 2-5
# 3-4
# e-1
# Las filas son: [['2', '5'], ['3', '4'], ['e', '1']]
# las dintancias 3
# las dintancias 4
# las dintancias 4
# las dintancias 4
# las dintancias 7
# las dintancias 8
# El expadido es: [Node <2-5 3-e 1-4>, Node <2-5 3-4 e-1>]
# Node <e-2 4-5 3-1>
# 71
# filas: [['e', '2'], ['4', '5'], ['3', '1']]
# 0
# 0
# las acciones ['4', '2']
# 0
# 0
# 1
# 0
#     [['4', '2'], ['e', '5'], ['3', '1']]
# resulte 4-2
# e-5
# 3-1
# Las filas son: [['4', '2'], ['e', '5'], ['3', '1']]
# las dintancias 3
# las dintancias 3
# las dintancias 4
# las dintancias 6
# las dintancias 8
# las dintancias 10
# 0
# 0
# 0
# 1
#     [['2', 'e'], ['4', '5'], ['3', '1']]
# resulte 2-e
# 4-5
# 3-1
# Las filas son: [['2', 'e'], ['4', '5'], ['3', '1']]
# las dintancias 3
# las dintancias 4
# las dintancias 5
# las dintancias 6
# las dintancias 8
# las dintancias 10
# El expadido es: [Node <4-2 e-5 3-1>, Node <2-e 4-5 3-1>]
# Node <2-5 4-e 3-1>
# 71
# filas: [['2', '5'], ['4', 'e'], ['3', '1']]
# 1
# 1
# las acciones ['5', '1', '4']
# 1
# 1
# 0
# 1
#     [['2', 'e'], ['4', '5'], ['3', '1']]
# resulte 2-e
# 4-5
# 3-1
# Las filas son: [['2', 'e'], ['4', '5'], ['3', '1']]
# las dintancias 3
# las dintancias 4
# las dintancias 5
# las dintancias 6
# las dintancias 8
# las dintancias 10
# 1
# 1
# 2
# 1
#     [['2', '5'], ['4', '1'], ['3', 'e']]
# resulte 2-5
# 4-1
# 3-e
# Las filas son: [['2', '5'], ['4', '1'], ['3', 'e']]
# las dintancias 2
# las dintancias 3
# las dintancias 4
# las dintancias 5
# las dintancias 8
# las dintancias 8
# 1
# 1
# 1
# 0
#     [['2', '5'], ['e', '4'], ['3', '1']]
# resulte 2-5
# e-4
# 3-1
# Las filas son: [['2', '5'], ['e', '4'], ['3', '1']]
# las dintancias 3
# las dintancias 4
# las dintancias 5
# las dintancias 5
# las dintancias 8
# las dintancias 10
# El expadido es: [Node <2-e 4-5 3-1>, Node <2-5 4-1 3-e>, Node <2-5 e-4 3-1>]
# Node <2-5 4-1 3-e>
# 71
# filas: [['2', '5'], ['4', '1'], ['3', 'e']]
# 2
# 1
# las acciones ['1', '3']
# 2
# 1
# 1
# 1
#     [['2', '5'], ['4', 'e'], ['3', '1']]
# resulte 2-5
# 4-e
# 3-1
# Las filas son: [['2', '5'], ['4', 'e'], ['3', '1']]
# las dintancias 3
# las dintancias 4
# las dintancias 5
# las dintancias 6
# las dintancias 9
# las dintancias 10
# 2
# 1
# 2
# 0
#     [['2', '5'], ['4', '1'], ['e', '3']]
# resulte 2-5
# 4-1
# e-3
# Las filas son: [['2', '5'], ['4', '1'], ['e', '3']]
# las dintancias 2
# las dintancias 3
# las dintancias 5
# las dintancias 6
# las dintancias 9
# las dintancias 10
# El expadido es: [Node <2-5 4-e 3-1>, Node <2-5 4-1 e-3>]
# Node <e-2 4-5 3-1>
# 71
# filas: [['e', '2'], ['4', '5'], ['3', '1']]
# 0
# 0
# las acciones ['4', '2']
# 0
# 0
# 1
# 0
#     [['4', '2'], ['e', '5'], ['3', '1']]
# resulte 4-2
# e-5
# 3-1
# Las filas son: [['4', '2'], ['e', '5'], ['3', '1']]
# las dintancias 3
# las dintancias 3
# las dintancias 4
# las dintancias 6
# las dintancias 8
# las dintancias 10
# 0
# 0
# 0
# 1
#     [['2', 'e'], ['4', '5'], ['3', '1']]
# resulte 2-e
# 4-5
# 3-1
# Las filas son: [['2', 'e'], ['4', '5'], ['3', '1']]
# las dintancias 3
# las dintancias 4
# las dintancias 5
# las dintancias 6
# las dintancias 8
# las dintancias 10
# El expadido es: [Node <4-2 e-5 3-1>, Node <2-e 4-5 3-1>]
# Node <4-2 3-5 e-1>
# 71
# filas: [['4', '2'], ['3', '5'], ['e', '1']]
# 2
# 0
# las acciones ['3', '1']
# 2
# 0
# 1
# 0
#     [['4', '2'], ['e', '5'], ['3', '1']]
# resulte 4-2
# e-5
# 3-1
# Las filas son: [['4', '2'], ['e', '5'], ['3', '1']]
# las dintancias 3
# las dintancias 3
# las dintancias 4
# las dintancias 6
# las dintancias 8
# las dintancias 10
# 2
# 0
# 2
# 1
#     [['4', '2'], ['3', '5'], ['1', 'e']]
# resulte 4-2
# 3-5
# 1-e
# Las filas son: [['4', '2'], ['3', '5'], ['1', 'e']]
# las dintancias 2
# las dintancias 2
# las dintancias 2
# las dintancias 4
# las dintancias 6
# las dintancias 6
# El expadido es: [Node <4-2 e-5 3-1>, Node <4-2 3-5 1-e>]
# Node <4-2 3-5 1-e>
# 71
# filas: [['4', '2'], ['3', '5'], ['1', 'e']]
# 2
# 1
# las acciones ['5', '1']
# 2
# 1
# 1
# 1
#     [['4', '2'], ['3', 'e'], ['1', '5']]
# resulte 4-2
# 3-e
# 1-5
# Las filas son: [['4', '2'], ['3', 'e'], ['1', '5']]
# las dintancias 2
# las dintancias 2
# las dintancias 2
# las dintancias 4
# las dintancias 5
# las dintancias 6
# 2
# 1
# 2
# 0
#     [['4', '2'], ['3', '5'], ['e', '1']]
# resulte 4-2
# 3-5
# e-1
# Las filas son: [['4', '2'], ['3', '5'], ['e', '1']]
# las dintancias 3
# las dintancias 3
# las dintancias 3
# las dintancias 5
# las dintancias 7
# las dintancias 8
# El expadido es: [Node <4-2 3-e 1-5>, Node <4-2 3-5 e-1>]
# Node <4-2 3-e 1-5>
# 71
# filas: [['4', '2'], ['3', 'e'], ['1', '5']]
# 1
# 1
# las acciones ['2', '5', '3']
# 1
# 1
# 0
# 1
#     [['4', 'e'], ['3', '2'], ['1', '5']]
# resulte 4-e
# 3-2
# 1-5
# Las filas son: [['4', 'e'], ['3', '2'], ['1', '5']]
# las dintancias 2
# las dintancias 3
# las dintancias 3
# las dintancias 5
# las dintancias 6
# las dintancias 8
# 1
# 1
# 2
# 1
#     [['4', '2'], ['3', '5'], ['1', 'e']]
# resulte 4-2
# 3-5
# 1-e
# Las filas son: [['4', '2'], ['3', '5'], ['1', 'e']]
# las dintancias 2
# las dintancias 2
# las dintancias 2
# las dintancias 4
# las dintancias 6
# las dintancias 6
# 1
# 1
# 1
# 0
#     [['4', '2'], ['e', '3'], ['1', '5']]
# resulte 4-2
# e-3
# 1-5
# Las filas son: [['4', '2'], ['e', '3'], ['1', '5']]
# las dintancias 2
# las dintancias 2
# las dintancias 3
# las dintancias 5
# las dintancias 6
# las dintancias 8
# El expadido es: [Node <4-e 3-2 1-5>, Node <4-2 3-5 1-e>, Node <4-2 e-3 1-5>]
# Node <4-2 5-1 e-3>
# 71
# filas: [['4', '2'], ['5', '1'], ['e', '3']]
# 2
# 0
# las acciones ['5', '3']
# 2
# 0
# 1
# 0
#     [['4', '2'], ['e', '1'], ['5', '3']]
# resulte 4-2
# e-1
# 5-3
# Las filas son: [['4', '2'], ['e', '1'], ['5', '3']]
# las dintancias 2
# las dintancias 2
# las dintancias 4
# las dintancias 6
# las dintancias 6
# las dintancias 8
# 2
# 0
# 2
# 1
#     [['4', '2'], ['5', '1'], ['3', 'e']]
# resulte 4-2
# 5-1
# 3-e
# Las filas son: [['4', '2'], ['5', '1'], ['3', 'e']]
# las dintancias 2
# las dintancias 2
# las dintancias 3
# las dintancias 5
# las dintancias 6
# las dintancias 6
# El expadido es: [Node <4-2 e-1 5-3>, Node <4-2 5-1 3-e>]
# Node <4-2 5-1 3-e>
# 71
# filas: [['4', '2'], ['5', '1'], ['3', 'e']]
# 2
# 1
# las acciones ['1', '3']
# 2
# 1
# 1
# 1
#     [['4', '2'], ['5', 'e'], ['3', '1']]
# resulte 4-2
# 5-e
# 3-1
# Las filas son: [['4', '2'], ['5', 'e'], ['3', '1']]
# las dintancias 3
# las dintancias 3
# las dintancias 4
# las dintancias 6
# las dintancias 7
# las dintancias 8
# 2
# 1
# 2
# 0
#     [['4', '2'], ['5', '1'], ['e', '3']]
# resulte 4-2
# 5-1
# e-3
# Las filas son: [['4', '2'], ['5', '1'], ['e', '3']]
# las dintancias 2
# las dintancias 2
# las dintancias 4
# las dintancias 6
# las dintancias 7
# las dintancias 8
# El expadido es: [Node <4-2 5-e 3-1>, Node <4-2 5-1 e-3>]
# Node <4-2 1-e 5-3>
# 71
# filas: [['4', '2'], ['1', 'e'], ['5', '3']]
# 1
# 1
# las acciones ['2', '3', '1']
# 1
# 1
# 0
# 1
#     [['4', 'e'], ['1', '2'], ['5', '3']]
# resulte 4-e
# 1-2
# 5-3
# Las filas son: [['4', 'e'], ['1', '2'], ['5', '3']]
# las dintancias 1
# las dintancias 2
# las dintancias 4
# las dintancias 6
# las dintancias 6
# las dintancias 8
# 1
# 1
# 2
# 1
#     [['4', '2'], ['1', '3'], ['5', 'e']]
# resulte 4-2
# 1-3
# 5-e
# Las filas son: [['4', '2'], ['1', '3'], ['5', 'e']]
# las dintancias 1
# las dintancias 1
# las dintancias 2
# las dintancias 4
# las dintancias 4
# las dintancias 4
# 1
# 1
# 1
# 0
#     [['4', '2'], ['e', '1'], ['5', '3']]
# resulte 4-2
# e-1
# 5-3
# Las filas son: [['4', '2'], ['e', '1'], ['5', '3']]
# las dintancias 2
# las dintancias 2
# las dintancias 4
# las dintancias 6
# las dintancias 6
# las dintancias 8
# El expadido es: [Node <4-e 1-2 5-3>, Node <4-2 1-3 5-e>, Node <4-2 e-1 5-3>]
# Node <4-2 1-3 5-e>
# 71
# filas: [['4', '2'], ['1', '3'], ['5', 'e']]
# 2
# 1
# las acciones ['3', '5']
# 2
# 1
# 1
# 1
#     [['4', '2'], ['1', 'e'], ['5', '3']]
# resulte 4-2
# 1-e
# 5-3
# Las filas son: [['4', '2'], ['1', 'e'], ['5', '3']]
# las dintancias 1
# las dintancias 1
# las dintancias 3
# las dintancias 5
# las dintancias 5
# las dintancias 6
# 2
# 1
# 2
# 0
#     [['4', '2'], ['1', '3'], ['e', '5']]
# resulte 4-2
# 1-3
# e-5
# Las filas son: [['4', '2'], ['1', '3'], ['e', '5']]
# las dintancias 1
# las dintancias 1
# las dintancias 2
# las dintancias 4
# las dintancias 5
# las dintancias 6
# El expadido es: [Node <4-2 1-e 5-3>, Node <4-2 1-3 e-5>]
# Node <2-5 4-e 3-1>
# 71
# filas: [['2', '5'], ['4', 'e'], ['3', '1']]
# 1
# 1
# las acciones ['5', '1', '4']
# 1
# 1
# 0
# 1
#     [['2', 'e'], ['4', '5'], ['3', '1']]
# resulte 2-e
# 4-5
# 3-1
# Las filas son: [['2', 'e'], ['4', '5'], ['3', '1']]
# las dintancias 3
# las dintancias 4
# las dintancias 5
# las dintancias 6
# las dintancias 8
# las dintancias 10
# 1
# 1
# 2
# 1
#     [['2', '5'], ['4', '1'], ['3', 'e']]
# resulte 2-5
# 4-1
# 3-e
# Las filas son: [['2', '5'], ['4', '1'], ['3', 'e']]
# las dintancias 2
# las dintancias 3
# las dintancias 4
# las dintancias 5
# las dintancias 8
# las dintancias 8
# 1
# 1
# 1
# 0
#     [['2', '5'], ['e', '4'], ['3', '1']]
# resulte 2-5
# e-4
# 3-1
# Las filas son: [['2', '5'], ['e', '4'], ['3', '1']]
# las dintancias 3
# las dintancias 4
# las dintancias 5
# las dintancias 5
# las dintancias 8
# las dintancias 10
# El expadido es: [Node <2-e 4-5 3-1>, Node <2-5 4-1 3-e>, Node <2-5 e-4 3-1>]
# Node <2-5 4-1 3-e>
# 71
# filas: [['2', '5'], ['4', '1'], ['3', 'e']]
# 2
# 1
# las acciones ['1', '3']
# 2
# 1
# 1
# 1
#     [['2', '5'], ['4', 'e'], ['3', '1']]
# resulte 2-5
# 4-e
# 3-1
# Las filas son: [['2', '5'], ['4', 'e'], ['3', '1']]
# las dintancias 3
# las dintancias 4
# las dintancias 5
# las dintancias 6
# las dintancias 9
# las dintancias 10
# 2
# 1
# 2
# 0
#     [['2', '5'], ['4', '1'], ['e', '3']]
# resulte 2-5
# 4-1
# e-3
# Las filas son: [['2', '5'], ['4', '1'], ['e', '3']]
# las dintancias 2
# las dintancias 3
# las dintancias 5
# las dintancias 6
# las dintancias 9
# las dintancias 10
# El expadido es: [Node <2-5 4-e 3-1>, Node <2-5 4-1 e-3>]
# Node <2-5 3-e 1-4>
# 71
# filas: [['2', '5'], ['3', 'e'], ['1', '4']]
# 1
# 1
# las acciones ['5', '4', '3']
# 1
# 1
# 0
# 1
#     [['2', 'e'], ['3', '5'], ['1', '4']]
# resulte 2-e
# 3-5
# 1-4
# Las filas son: [['2', 'e'], ['3', '5'], ['1', '4']]
# las dintancias 2
# las dintancias 3
# las dintancias 3
# las dintancias 4
# las dintancias 6
# las dintancias 8
# 1
# 1
# 2
# 1
#     [['2', '5'], ['3', '4'], ['1', 'e']]
# resulte 2-5
# 3-4
# 1-e
# Las filas son: [['2', '5'], ['3', '4'], ['1', 'e']]
# las dintancias 2
# las dintancias 3
# las dintancias 3
# las dintancias 3
# las dintancias 6
# las dintancias 6
# 1
# 1
# 1
# 0
#     [['2', '5'], ['e', '3'], ['1', '4']]
# resulte 2-5
# e-3
# 1-4
# Las filas son: [['2', '5'], ['e', '3'], ['1', '4']]
# las dintancias 2
# las dintancias 3
# las dintancias 4
# las dintancias 5
# las dintancias 8
# las dintancias 10
# El expadido es: [Node <2-e 3-5 1-4>, Node <2-5 3-4 1-e>, Node <2-5 e-3 1-4>]
# Node <2-5 3-4 1-e>
# 71
# filas: [['2', '5'], ['3', '4'], ['1', 'e']]
# 2
# 1
# las acciones ['4', '1']
# 2
# 1
# 1
# 1
#     [['2', '5'], ['3', 'e'], ['1', '4']]
# resulte 2-5
# 3-e
# 1-4
# Las filas son: [['2', '5'], ['3', 'e'], ['1', '4']]
# las dintancias 2
# las dintancias 3
# las dintancias 3
# las dintancias 4
# las dintancias 7
# las dintancias 8
# 2
# 1
# 2
# 0
#     [['2', '5'], ['3', '4'], ['e', '1']]
# resulte 2-5
# 3-4
# e-1
# Las filas son: [['2', '5'], ['3', '4'], ['e', '1']]
# las dintancias 3
# las dintancias 4
# las dintancias 4
# las dintancias 4
# las dintancias 7
# las dintancias 8
# El expadido es: [Node <2-5 3-e 1-4>, Node <2-5 3-4 e-1>]
# Node <4-2 3-e 1-5>
# 71
# filas: [['4', '2'], ['3', 'e'], ['1', '5']]
# 1
# 1
# las acciones ['2', '5', '3']
# 1
# 1
# 0
# 1
#     [['4', 'e'], ['3', '2'], ['1', '5']]
# resulte 4-e
# 3-2
# 1-5
# Las filas son: [['4', 'e'], ['3', '2'], ['1', '5']]
# las dintancias 2
# las dintancias 3
# las dintancias 3
# las dintancias 5
# las dintancias 6
# las dintancias 8
# 1
# 1
# 2
# 1
#     [['4', '2'], ['3', '5'], ['1', 'e']]
# resulte 4-2
# 3-5
# 1-e
# Las filas son: [['4', '2'], ['3', '5'], ['1', 'e']]
# las dintancias 2
# las dintancias 2
# las dintancias 2
# las dintancias 4
# las dintancias 6
# las dintancias 6
# 1
# 1
# 1
# 0
#     [['4', '2'], ['e', '3'], ['1', '5']]
# resulte 4-2
# e-3
# 1-5
# Las filas son: [['4', '2'], ['e', '3'], ['1', '5']]
# las dintancias 2
# las dintancias 2
# las dintancias 3
# las dintancias 5
# las dintancias 6
# las dintancias 8
# El expadido es: [Node <4-e 3-2 1-5>, Node <4-2 3-5 1-e>, Node <4-2 e-3 1-5>]
# Node <e-5 2-4 3-1>
# 71
# filas: [['e', '5'], ['2', '4'], ['3', '1']]
# 0
# 0
# las acciones ['2', '5']
# 0
# 0
# 1
# 0
#     [['2', '5'], ['e', '4'], ['3', '1']]
# resulte 2-5
# e-4
# 3-1
# Las filas son: [['2', '5'], ['e', '4'], ['3', '1']]
# las dintancias 3
# las dintancias 4
# las dintancias 5
# las dintancias 5
# las dintancias 8
# las dintancias 10
# 0
# 0
# 0
# 1
#     [['5', 'e'], ['2', '4'], ['3', '1']]
# resulte 5-e
# 2-4
# 3-1
# Las filas son: [['5', 'e'], ['2', '4'], ['3', '1']]
# las dintancias 3
# las dintancias 5
# las dintancias 6
# las dintancias 6
# las dintancias 8
# las dintancias 10
# El expadido es: [Node <2-5 e-4 3-1>, Node <5-e 2-4 3-1>]
# Node <2-5 e-4 3-1>
# 71
# filas: [['2', '5'], ['e', '4'], ['3', '1']]
# 1
# 0
# las acciones ['2', '3', '4']
# 1
# 0
# 0
# 0
#     [['e', '5'], ['2', '4'], ['3', '1']]
# resulte e-5
# 2-4
# 3-1
# Las filas son: [['e', '5'], ['2', '4'], ['3', '1']]
# las dintancias 3
# las dintancias 5
# las dintancias 6
# las dintancias 6
# las dintancias 9
# las dintancias 12
# 1
# 0
# 2
# 0
#     [['2', '5'], ['3', '4'], ['e', '1']]
# resulte 2-5
# 3-4
# e-1
# Las filas son: [['2', '5'], ['3', '4'], ['e', '1']]
# las dintancias 3
# las dintancias 4
# las dintancias 4
# las dintancias 4
# las dintancias 7
# las dintancias 8
# 1
# 0
# 1
# 1
#     [['2', '5'], ['4', 'e'], ['3', '1']]
# resulte 2-5
# 4-e
# 3-1
# Las filas son: [['2', '5'], ['4', 'e'], ['3', '1']]
# las dintancias 3
# las dintancias 4
# las dintancias 5
# las dintancias 6
# las dintancias 9
# las dintancias 10
# El expadido es: [Node <e-5 2-4 3-1>, Node <2-5 3-4 e-1>, Node <2-5 4-e 3-1>]
# Node <2-5 3-4 e-1>
# 71
# filas: [['2', '5'], ['3', '4'], ['e', '1']]
# 2
# 0
# las acciones ['3', '1']
# 2
# 0
# 1
# 0
#     [['2', '5'], ['e', '4'], ['3', '1']]
# resulte 2-5
# e-4
# 3-1
# Las filas son: [['2', '5'], ['e', '4'], ['3', '1']]
# las dintancias 3
# las dintancias 4
# las dintancias 5
# las dintancias 5
# las dintancias 8
# las dintancias 10
# 2
# 0
# 2
# 1
#     [['2', '5'], ['3', '4'], ['1', 'e']]
# resulte 2-5
# 3-4
# 1-e
# Las filas son: [['2', '5'], ['3', '4'], ['1', 'e']]
# las dintancias 2
# las dintancias 3
# las dintancias 3
# las dintancias 3
# las dintancias 6
# las dintancias 6
# El expadido es: [Node <2-5 e-4 3-1>, Node <2-5 3-4 1-e>]
# Node <2-5 3-4 1-e>
# 71
# filas: [['2', '5'], ['3', '4'], ['1', 'e']]
# 2
# 1
# las acciones ['4', '1']
# 2
# 1
# 1
# 1
#     [['2', '5'], ['3', 'e'], ['1', '4']]
# resulte 2-5
# 3-e
# 1-4
# Las filas son: [['2', '5'], ['3', 'e'], ['1', '4']]
# las dintancias 2
# las dintancias 3
# las dintancias 3
# las dintancias 4
# las dintancias 7
# las dintancias 8
# 2
# 1
# 2
# 0
#     [['2', '5'], ['3', '4'], ['e', '1']]
# resulte 2-5
# 3-4
# e-1
# Las filas son: [['2', '5'], ['3', '4'], ['e', '1']]
# las dintancias 3
# las dintancias 4
# las dintancias 4
# las dintancias 4
# las dintancias 7
# las dintancias 8
# El expadido es: [Node <2-5 3-e 1-4>, Node <2-5 3-4 e-1>]
# Node <5-e 2-4 3-1>
# 71
# filas: [['5', 'e'], ['2', '4'], ['3', '1']]
# 0
# 1
# las acciones ['4', '5']
# 0
# 1
# 1
# 1
#     [['5', '4'], ['2', 'e'], ['3', '1']]
# resulte 5-4
# 2-e
# 3-1
# Las filas son: [['5', '4'], ['2', 'e'], ['3', '1']]
# las dintancias 3
# las dintancias 5
# las dintancias 6
# las dintancias 7
# las dintancias 9
# las dintancias 10
# 0
# 1
# 0
# 0
#     [['e', '5'], ['2', '4'], ['3', '1']]
# resulte e-5
# 2-4
# 3-1
# Las filas son: [['e', '5'], ['2', '4'], ['3', '1']]
# las dintancias 3
# las dintancias 5
# las dintancias 6
# las dintancias 6
# las dintancias 9
# las dintancias 12
# El expadido es: [Node <5-4 2-e 3-1>, Node <e-5 2-4 3-1>]
# Node <e-2 4-5 3-1>
# 71
# filas: [['e', '2'], ['4', '5'], ['3', '1']]
# 0
# 0
# las acciones ['4', '2']
# 0
# 0
# 1
# 0
#     [['4', '2'], ['e', '5'], ['3', '1']]
# resulte 4-2
# e-5
# 3-1
# Las filas son: [['4', '2'], ['e', '5'], ['3', '1']]
# las dintancias 3
# las dintancias 3
# las dintancias 4
# las dintancias 6
# las dintancias 8
# las dintancias 10
# 0
# 0
# 0
# 1
#     [['2', 'e'], ['4', '5'], ['3', '1']]
# resulte 2-e
# 4-5
# 3-1
# Las filas son: [['2', 'e'], ['4', '5'], ['3', '1']]
# las dintancias 3
# las dintancias 4
# las dintancias 5
# las dintancias 6
# las dintancias 8
# las dintancias 10
# El expadido es: [Node <4-2 e-5 3-1>, Node <2-e 4-5 3-1>]
# Node <4-2 3-e 1-5>
# 71
# filas: [['4', '2'], ['3', 'e'], ['1', '5']]
# 1
# 1
# las acciones ['2', '5', '3']
# 1
# 1
# 0
# 1
#     [['4', 'e'], ['3', '2'], ['1', '5']]
# resulte 4-e
# 3-2
# 1-5
# Las filas son: [['4', 'e'], ['3', '2'], ['1', '5']]
# las dintancias 2
# las dintancias 3
# las dintancias 3
# las dintancias 5
# las dintancias 6
# las dintancias 8
# 1
# 1
# 2
# 1
#     [['4', '2'], ['3', '5'], ['1', 'e']]
# resulte 4-2
# 3-5
# 1-e
# Las filas son: [['4', '2'], ['3', '5'], ['1', 'e']]
# las dintancias 2
# las dintancias 2
# las dintancias 2
# las dintancias 4
# las dintancias 6
# las dintancias 6
# 1
# 1
# 1
# 0
#     [['4', '2'], ['e', '3'], ['1', '5']]
# resulte 4-2
# e-3
# 1-5
# Las filas son: [['4', '2'], ['e', '3'], ['1', '5']]
# las dintancias 2
# las dintancias 2
# las dintancias 3
# las dintancias 5
# las dintancias 6
# las dintancias 8
# El expadido es: [Node <4-e 3-2 1-5>, Node <4-2 3-5 1-e>, Node <4-2 e-3 1-5>]
# Node <4-2 3-e 1-5>
# 71
# filas: [['4', '2'], ['3', 'e'], ['1', '5']]
# 1
# 1
# las acciones ['2', '5', '3']
# 1
# 1
# 0
# 1
#     [['4', 'e'], ['3', '2'], ['1', '5']]
# resulte 4-e
# 3-2
# 1-5
# Las filas son: [['4', 'e'], ['3', '2'], ['1', '5']]
# las dintancias 2
# las dintancias 3
# las dintancias 3
# las dintancias 5
# las dintancias 6
# las dintancias 8
# 1
# 1
# 2
# 1
#     [['4', '2'], ['3', '5'], ['1', 'e']]
# resulte 4-2
# 3-5
# 1-e
# Las filas son: [['4', '2'], ['3', '5'], ['1', 'e']]
# las dintancias 2
# las dintancias 2
# las dintancias 2
# las dintancias 4
# las dintancias 6
# las dintancias 6
# 1
# 1
# 1
# 0
#     [['4', '2'], ['e', '3'], ['1', '5']]
# resulte 4-2
# e-3
# 1-5
# Las filas son: [['4', '2'], ['e', '3'], ['1', '5']]
# las dintancias 2
# las dintancias 2
# las dintancias 3
# las dintancias 5
# las dintancias 6
# las dintancias 8
# El expadido es: [Node <4-e 3-2 1-5>, Node <4-2 3-5 1-e>, Node <4-2 e-3 1-5>]
# Node <2-5 3-4 e-1>
# 71
# filas: [['2', '5'], ['3', '4'], ['e', '1']]
# 2
# 0
# las acciones ['3', '1']
# 2
# 0
# 1
# 0
#     [['2', '5'], ['e', '4'], ['3', '1']]
# resulte 2-5
# e-4
# 3-1
# Las filas son: [['2', '5'], ['e', '4'], ['3', '1']]
# las dintancias 3
# las dintancias 4
# las dintancias 5
# las dintancias 5
# las dintancias 8
# las dintancias 10
# 2
# 0
# 2
# 1
#     [['2', '5'], ['3', '4'], ['1', 'e']]
# resulte 2-5
# 3-4
# 1-e
# Las filas son: [['2', '5'], ['3', '4'], ['1', 'e']]
# las dintancias 2
# las dintancias 3
# las dintancias 3
# las dintancias 3
# las dintancias 6
# las dintancias 6
# El expadido es: [Node <2-5 e-4 3-1>, Node <2-5 3-4 1-e>]
# Node <2-5 3-4 1-e>
# 71
# filas: [['2', '5'], ['3', '4'], ['1', 'e']]
# 2
# 1
# las acciones ['4', '1']
# 2
# 1
# 1
# 1
#     [['2', '5'], ['3', 'e'], ['1', '4']]
# resulte 2-5
# 3-e
# 1-4
# Las filas son: [['2', '5'], ['3', 'e'], ['1', '4']]
# las dintancias 2
# las dintancias 3
# las dintancias 3
# las dintancias 4
# las dintancias 7
# las dintancias 8
# 2
# 1
# 2
# 0
#     [['2', '5'], ['3', '4'], ['e', '1']]
# resulte 2-5
# 3-4
# e-1
# Las filas son: [['2', '5'], ['3', '4'], ['e', '1']]
# las dintancias 3
# las dintancias 4
# las dintancias 4
# las dintancias 4
# las dintancias 7
# las dintancias 8
# El expadido es: [Node <2-5 3-e 1-4>, Node <2-5 3-4 e-1>]
# Node <4-2 3-e 1-5>
# 71
# filas: [['4', '2'], ['3', 'e'], ['1', '5']]
# 1
# 1
# las acciones ['2', '5', '3']
# 1
# 1
# 0
# 1
#     [['4', 'e'], ['3', '2'], ['1', '5']]
# resulte 4-e
# 3-2
# 1-5
# Las filas son: [['4', 'e'], ['3', '2'], ['1', '5']]
# las dintancias 2
# las dintancias 3
# las dintancias 3
# las dintancias 5
# las dintancias 6
# las dintancias 8
# 1
# 1
# 2
# 1
#     [['4', '2'], ['3', '5'], ['1', 'e']]
# resulte 4-2
# 3-5
# 1-e
# Las filas son: [['4', '2'], ['3', '5'], ['1', 'e']]
# las dintancias 2
# las dintancias 2
# las dintancias 2
# las dintancias 4
# las dintancias 6
# las dintancias 6
# 1
# 1
# 1
# 0
#     [['4', '2'], ['e', '3'], ['1', '5']]
# resulte 4-2
# e-3
# 1-5
# Las filas son: [['4', '2'], ['e', '3'], ['1', '5']]
# las dintancias 2
# las dintancias 2
# las dintancias 3
# las dintancias 5
# las dintancias 6
# las dintancias 8
# El expadido es: [Node <4-e 3-2 1-5>, Node <4-2 3-5 1-e>, Node <4-2 e-3 1-5>]
# Node <2-5 4-e 3-1>
# 71
# filas: [['2', '5'], ['4', 'e'], ['3', '1']]
# 1
# 1
# las acciones ['5', '1', '4']
# 1
# 1
# 0
# 1
#     [['2', 'e'], ['4', '5'], ['3', '1']]
# resulte 2-e
# 4-5
# 3-1
# Las filas son: [['2', 'e'], ['4', '5'], ['3', '1']]
# las dintancias 3
# las dintancias 4
# las dintancias 5
# las dintancias 6
# las dintancias 8
# las dintancias 10
# 1
# 1
# 2
# 1
#     [['2', '5'], ['4', '1'], ['3', 'e']]
# resulte 2-5
# 4-1
# 3-e
# Las filas son: [['2', '5'], ['4', '1'], ['3', 'e']]
# las dintancias 2
# las dintancias 3
# las dintancias 4
# las dintancias 5
# las dintancias 8
# las dintancias 8
# 1
# 1
# 1
# 0
#     [['2', '5'], ['e', '4'], ['3', '1']]
# resulte 2-5
# e-4
# 3-1
# Las filas son: [['2', '5'], ['e', '4'], ['3', '1']]
# las dintancias 3
# las dintancias 4
# las dintancias 5
# las dintancias 5
# las dintancias 8
# las dintancias 10
# El expadido es: [Node <2-e 4-5 3-1>, Node <2-5 4-1 3-e>, Node <2-5 e-4 3-1>]
# Node <2-5 4-1 3-e>
# 71
# filas: [['2', '5'], ['4', '1'], ['3', 'e']]
# 2
# 1
# las acciones ['1', '3']
# 2
# 1
# 1
# 1
#     [['2', '5'], ['4', 'e'], ['3', '1']]
# resulte 2-5
# 4-e
# 3-1
# Las filas son: [['2', '5'], ['4', 'e'], ['3', '1']]
# las dintancias 3
# las dintancias 4
# las dintancias 5
# las dintancias 6
# las dintancias 9
# las dintancias 10
# 2
# 1
# 2
# 0
#     [['2', '5'], ['4', '1'], ['e', '3']]
# resulte 2-5
# 4-1
# e-3
# Las filas son: [['2', '5'], ['4', '1'], ['e', '3']]
# las dintancias 2
# las dintancias 3
# las dintancias 5
# las dintancias 6
# las dintancias 9
# las dintancias 10
# El expadido es: [Node <2-5 4-e 3-1>, Node <2-5 4-1 e-3>]
# Node <2-5 3-e 1-4>
# 71
# filas: [['2', '5'], ['3', 'e'], ['1', '4']]
# 1
# 1
# las acciones ['5', '4', '3']
# 1
# 1
# 0
# 1
#     [['2', 'e'], ['3', '5'], ['1', '4']]
# resulte 2-e
# 3-5
# 1-4
# Las filas son: [['2', 'e'], ['3', '5'], ['1', '4']]
# las dintancias 2
# las dintancias 3
# las dintancias 3
# las dintancias 4
# las dintancias 6
# las dintancias 8
# 1
# 1
# 2
# 1
#     [['2', '5'], ['3', '4'], ['1', 'e']]
# resulte 2-5
# 3-4
# 1-e
# Las filas son: [['2', '5'], ['3', '4'], ['1', 'e']]
# las dintancias 2
# las dintancias 3
# las dintancias 3
# las dintancias 3
# las dintancias 6
# las dintancias 6
# 1
# 1
# 1
# 0
#     [['2', '5'], ['e', '3'], ['1', '4']]
# resulte 2-5
# e-3
# 1-4
# Las filas son: [['2', '5'], ['e', '3'], ['1', '4']]
# las dintancias 2
# las dintancias 3
# las dintancias 4
# las dintancias 5
# las dintancias 8
# las dintancias 10
# El expadido es: [Node <2-e 3-5 1-4>, Node <2-5 3-4 1-e>, Node <2-5 e-3 1-4>]
# Node <2-5 3-4 1-e>
# 71
# filas: [['2', '5'], ['3', '4'], ['1', 'e']]
# 2
# 1
# las acciones ['4', '1']
# 2
# 1
# 1
# 1
#     [['2', '5'], ['3', 'e'], ['1', '4']]
# resulte 2-5
# 3-e
# 1-4
# Las filas son: [['2', '5'], ['3', 'e'], ['1', '4']]
# las dintancias 2
# las dintancias 3
# las dintancias 3
# las dintancias 4
# las dintancias 7
# las dintancias 8
# 2
# 1
# 2
# 0
#     [['2', '5'], ['3', '4'], ['e', '1']]
# resulte 2-5
# 3-4
# e-1
# Las filas son: [['2', '5'], ['3', '4'], ['e', '1']]
# las dintancias 3
# las dintancias 4
# las dintancias 4
# las dintancias 4
# las dintancias 7
# las dintancias 8
# El expadido es: [Node <2-5 3-e 1-4>, Node <2-5 3-4 e-1>]
# Node <2-5 3-4 e-1>
# 71
# filas: [['2', '5'], ['3', '4'], ['e', '1']]
# 2
# 0
# las acciones ['3', '1']
# 2
# 0
# 1
# 0
#     [['2', '5'], ['e', '4'], ['3', '1']]
# resulte 2-5
# e-4
# 3-1
# Las filas son: [['2', '5'], ['e', '4'], ['3', '1']]
# las dintancias 3
# las dintancias 4
# las dintancias 5
# las dintancias 5
# las dintancias 8
# las dintancias 10
# 2
# 0
# 2
# 1
#     [['2', '5'], ['3', '4'], ['1', 'e']]
# resulte 2-5
# 3-4
# 1-e
# Las filas son: [['2', '5'], ['3', '4'], ['1', 'e']]
# las dintancias 2
# las dintancias 3
# las dintancias 3
# las dintancias 3
# las dintancias 6
# las dintancias 6
# El expadido es: [Node <2-5 e-4 3-1>, Node <2-5 3-4 1-e>]
# Node <2-5 3-4 1-e>
# 71
# filas: [['2', '5'], ['3', '4'], ['1', 'e']]
# 2
# 1
# las acciones ['4', '1']
# 2
# 1
# 1
# 1
#     [['2', '5'], ['3', 'e'], ['1', '4']]
# resulte 2-5
# 3-e
# 1-4
# Las filas son: [['2', '5'], ['3', 'e'], ['1', '4']]
# las dintancias 2
# las dintancias 3
# las dintancias 3
# las dintancias 4
# las dintancias 7
# las dintancias 8
# 2
# 1
# 2
# 0
#     [['2', '5'], ['3', '4'], ['e', '1']]
# resulte 2-5
# 3-4
# e-1
# Las filas son: [['2', '5'], ['3', '4'], ['e', '1']]
# las dintancias 3
# las dintancias 4
# las dintancias 4
# las dintancias 4
# las dintancias 7
# las dintancias 8
# El expadido es: [Node <2-5 3-e 1-4>, Node <2-5 3-4 e-1>]
# Node <5-4 2-e 3-1>
# 71
# filas: [['5', '4'], ['2', 'e'], ['3', '1']]
# 1
# 1
# las acciones ['4', '1', '2']
# 1
# 1
# 0
# 1
#     [['5', 'e'], ['2', '4'], ['3', '1']]
# resulte 5-e
# 2-4
# 3-1
# Las filas son: [['5', 'e'], ['2', '4'], ['3', '1']]
# las dintancias 3
# las dintancias 5
# las dintancias 6
# las dintancias 6
# las dintancias 8
# las dintancias 10
# 1
# 1
# 2
# 1
#     [['5', '4'], ['2', '1'], ['3', 'e']]
# resulte 5-4
# 2-1
# 3-e
# Las filas son: [['5', '4'], ['2', '1'], ['3', 'e']]
# las dintancias 2
# las dintancias 4
# las dintancias 5
# las dintancias 6
# las dintancias 8
# las dintancias 8
# 1
# 1
# 1
# 0
#     [['5', '4'], ['e', '2'], ['3', '1']]
# resulte 5-4
# e-2
# 3-1
# Las filas son: [['5', '4'], ['e', '2'], ['3', '1']]
# las dintancias 3
# las dintancias 4
# las dintancias 5
# las dintancias 6
# las dintancias 8
# las dintancias 10
# El expadido es: [Node <5-e 2-4 3-1>, Node <5-4 2-1 3-e>, Node <5-4 e-2 3-1>]
# Node <5-4 2-1 3-e>
# 71
# filas: [['5', '4'], ['2', '1'], ['3', 'e']]
# 2
# 1
# las acciones ['1', '3']
# 2
# 1
# 1
# 1
#     [['5', '4'], ['2', 'e'], ['3', '1']]
# resulte 5-4
# 2-e
# 3-1
# Las filas son: [['5', '4'], ['2', 'e'], ['3', '1']]
# las dintancias 3
# las dintancias 5
# las dintancias 6
# las dintancias 7
# las dintancias 9
# las dintancias 10
# 2
# 1
# 2
# 0
#     [['5', '4'], ['2', '1'], ['e', '3']]
# resulte 5-4
# 2-1
# e-3
# Las filas son: [['5', '4'], ['2', '1'], ['e', '3']]
# las dintancias 2
# las dintancias 4
# las dintancias 6
# las dintancias 7
# las dintancias 9
# las dintancias 10
# El expadido es: [Node <5-4 2-e 3-1>, Node <5-4 2-1 e-3>]
# Node <4-2 3-e 1-5>
# 71
# filas: [['4', '2'], ['3', 'e'], ['1', '5']]
# 1
# 1
# las acciones ['2', '5', '3']
# 1
# 1
# 0
# 1
#     [['4', 'e'], ['3', '2'], ['1', '5']]
# resulte 4-e
# 3-2
# 1-5
# Las filas son: [['4', 'e'], ['3', '2'], ['1', '5']]
# las dintancias 2
# las dintancias 3
# las dintancias 3
# las dintancias 5
# las dintancias 6
# las dintancias 8
# 1
# 1
# 2
# 1
#     [['4', '2'], ['3', '5'], ['1', 'e']]
# resulte 4-2
# 3-5
# 1-e
# Las filas son: [['4', '2'], ['3', '5'], ['1', 'e']]
# las dintancias 2
# las dintancias 2
# las dintancias 2
# las dintancias 4
# las dintancias 6
# las dintancias 6
# 1
# 1
# 1
# 0
#     [['4', '2'], ['e', '3'], ['1', '5']]
# resulte 4-2
# e-3
# 1-5
# Las filas son: [['4', '2'], ['e', '3'], ['1', '5']]
# las dintancias 2
# las dintancias 2
# las dintancias 3
# las dintancias 5
# las dintancias 6
# las dintancias 8
# El expadido es: [Node <4-e 3-2 1-5>, Node <4-2 3-5 1-e>, Node <4-2 e-3 1-5>]
# Node <e-4 3-2 1-5>
# 71
# filas: [['e', '4'], ['3', '2'], ['1', '5']]
# 0
# 0
# las acciones ['3', '4']
# 0
# 0
# 1
# 0
#     [['3', '4'], ['e', '2'], ['1', '5']]
# resulte 3-4
# e-2
# 1-5
# Las filas son: [['3', '4'], ['e', '2'], ['1', '5']]
# las dintancias 2
# las dintancias 3
# las dintancias 4
# las dintancias 5
# las dintancias 6
# las dintancias 8
# 0
# 0
# 0
# 1
#     [['4', 'e'], ['3', '2'], ['1', '5']]
# resulte 4-e
# 3-2
# 1-5
# Las filas son: [['4', 'e'], ['3', '2'], ['1', '5']]
# las dintancias 2
# las dintancias 3
# las dintancias 3
# las dintancias 5
# las dintancias 6
# las dintancias 8
# El expadido es: [Node <3-4 e-2 1-5>, Node <4-e 3-2 1-5>]
# Node <e-2 4-1 5-3>
# 71
# filas: [['e', '2'], ['4', '1'], ['5', '3']]
# 0
# 0
# las acciones ['4', '2']
# 0
# 0
# 1
# 0
#     [['4', '2'], ['e', '1'], ['5', '3']]
# resulte 4-2
# e-1
# 5-3
# Las filas son: [['4', '2'], ['e', '1'], ['5', '3']]
# las dintancias 2
# las dintancias 2
# las dintancias 4
# las dintancias 6
# las dintancias 6
# las dintancias 8
# 0
# 0
# 0
# 1
#     [['2', 'e'], ['4', '1'], ['5', '3']]
# resulte 2-e
# 4-1
# 5-3
# Las filas son: [['2', 'e'], ['4', '1'], ['5', '3']]
# las dintancias 2
# las dintancias 3
# las dintancias 5
# las dintancias 6
# las dintancias 6
# las dintancias 8
# El expadido es: [Node <4-2 e-1 5-3>, Node <2-e 4-1 5-3>]
# Node <4-2 3-5 e-1>
# 71
# filas: [['4', '2'], ['3', '5'], ['e', '1']]
# 2
# 0
# las acciones ['3', '1']
# 2
# 0
# 1
# 0
#     [['4', '2'], ['e', '5'], ['3', '1']]
# resulte 4-2
# e-5
# 3-1
# Las filas son: [['4', '2'], ['e', '5'], ['3', '1']]
# las dintancias 3
# las dintancias 3
# las dintancias 4
# las dintancias 6
# las dintancias 8
# las dintancias 10
# 2
# 0
# 2
# 1
#     [['4', '2'], ['3', '5'], ['1', 'e']]
# resulte 4-2
# 3-5
# 1-e
# Las filas son: [['4', '2'], ['3', '5'], ['1', 'e']]
# las dintancias 2
# las dintancias 2
# las dintancias 2
# las dintancias 4
# las dintancias 6
# las dintancias 6
# El expadido es: [Node <4-2 e-5 3-1>, Node <4-2 3-5 1-e>]
# Node <4-2 3-5 1-e>
# 71
# filas: [['4', '2'], ['3', '5'], ['1', 'e']]
# 2
# 1
# las acciones ['5', '1']
# 2
# 1
# 1
# 1
#     [['4', '2'], ['3', 'e'], ['1', '5']]
# resulte 4-2
# 3-e
# 1-5
# Las filas son: [['4', '2'], ['3', 'e'], ['1', '5']]
# las dintancias 2
# las dintancias 2
# las dintancias 2
# las dintancias 4
# las dintancias 5
# las dintancias 6
# 2
# 1
# 2
# 0
#     [['4', '2'], ['3', '5'], ['e', '1']]
# resulte 4-2
# 3-5
# e-1
# Las filas son: [['4', '2'], ['3', '5'], ['e', '1']]
# las dintancias 3
# las dintancias 3
# las dintancias 3
# las dintancias 5
# las dintancias 7
# las dintancias 8
# El expadido es: [Node <4-2 3-e 1-5>, Node <4-2 3-5 e-1>]
# Node <e-2 4-5 3-1>
# 71
# filas: [['e', '2'], ['4', '5'], ['3', '1']]
# 0
# 0
# las acciones ['4', '2']
# 0
# 0
# 1
# 0
#     [['4', '2'], ['e', '5'], ['3', '1']]
# resulte 4-2
# e-5
# 3-1
# Las filas son: [['4', '2'], ['e', '5'], ['3', '1']]
# las dintancias 3
# las dintancias 3
# las dintancias 4
# las dintancias 6
# las dintancias 8
# las dintancias 10
# 0
# 0
# 0
# 1
#     [['2', 'e'], ['4', '5'], ['3', '1']]
# resulte 2-e
# 4-5
# 3-1
# Las filas son: [['2', 'e'], ['4', '5'], ['3', '1']]
# las dintancias 3
# las dintancias 4
# las dintancias 5
# las dintancias 6
# las dintancias 8
# las dintancias 10
# El expadido es: [Node <4-2 e-5 3-1>, Node <2-e 4-5 3-1>]
# Node <e-2 4-5 3-1>
# 71
# filas: [['e', '2'], ['4', '5'], ['3', '1']]
# 0
# 0
# las acciones ['4', '2']
# 0
# 0
# 1
# 0
#     [['4', '2'], ['e', '5'], ['3', '1']]
# resulte 4-2
# e-5
# 3-1
# Las filas son: [['4', '2'], ['e', '5'], ['3', '1']]
# las dintancias 3
# las dintancias 3
# las dintancias 4
# las dintancias 6
# las dintancias 8
# las dintancias 10
# 0
# 0
# 0
# 1
#     [['2', 'e'], ['4', '5'], ['3', '1']]
# resulte 2-e
# 4-5
# 3-1
# Las filas son: [['2', 'e'], ['4', '5'], ['3', '1']]
# las dintancias 3
# las dintancias 4
# las dintancias 5
# las dintancias 6
# las dintancias 8
# las dintancias 10
# El expadido es: [Node <4-2 e-5 3-1>, Node <2-e 4-5 3-1>]
# Node <2-5 3-e 1-4>
# 71
# filas: [['2', '5'], ['3', 'e'], ['1', '4']]
# 1
# 1
# las acciones ['5', '4', '3']
# 1
# 1
# 0
# 1
#     [['2', 'e'], ['3', '5'], ['1', '4']]
# resulte 2-e
# 3-5
# 1-4
# Las filas son: [['2', 'e'], ['3', '5'], ['1', '4']]
# las dintancias 2
# las dintancias 3
# las dintancias 3
# las dintancias 4
# las dintancias 6
# las dintancias 8
# 1
# 1
# 2
# 1
#     [['2', '5'], ['3', '4'], ['1', 'e']]
# resulte 2-5
# 3-4
# 1-e
# Las filas son: [['2', '5'], ['3', '4'], ['1', 'e']]
# las dintancias 2
# las dintancias 3
# las dintancias 3
# las dintancias 3
# las dintancias 6
# las dintancias 6
# 1
# 1
# 1
# 0
#     [['2', '5'], ['e', '3'], ['1', '4']]
# resulte 2-5
# e-3
# 1-4
# Las filas son: [['2', '5'], ['e', '3'], ['1', '4']]
# las dintancias 2
# las dintancias 3
# las dintancias 4
# las dintancias 5
# las dintancias 8
# las dintancias 10
# El expadido es: [Node <2-e 3-5 1-4>, Node <2-5 3-4 1-e>, Node <2-5 e-3 1-4>]
# Node <2-5 3-4 1-e>
# 71
# filas: [['2', '5'], ['3', '4'], ['1', 'e']]
# 2
# 1
# las acciones ['4', '1']
# 2
# 1
# 1
# 1
#     [['2', '5'], ['3', 'e'], ['1', '4']]
# resulte 2-5
# 3-e
# 1-4
# Las filas son: [['2', '5'], ['3', 'e'], ['1', '4']]
# las dintancias 2
# las dintancias 3
# las dintancias 3
# las dintancias 4
# las dintancias 7
# las dintancias 8
# 2
# 1
# 2
# 0
#     [['2', '5'], ['3', '4'], ['e', '1']]
# resulte 2-5
# 3-4
# e-1
# Las filas son: [['2', '5'], ['3', '4'], ['e', '1']]
# las dintancias 3
# las dintancias 4
# las dintancias 4
# las dintancias 4
# las dintancias 7
# las dintancias 8
# El expadido es: [Node <2-5 3-e 1-4>, Node <2-5 3-4 e-1>]
# Node <4-2 3-e 1-5>
# 71
# filas: [['4', '2'], ['3', 'e'], ['1', '5']]
# 1
# 1
# las acciones ['2', '5', '3']
# 1
# 1
# 0
# 1
#     [['4', 'e'], ['3', '2'], ['1', '5']]
# resulte 4-e
# 3-2
# 1-5
# Las filas son: [['4', 'e'], ['3', '2'], ['1', '5']]
# las dintancias 2
# las dintancias 3
# las dintancias 3
# las dintancias 5
# las dintancias 6
# las dintancias 8
# 1
# 1
# 2
# 1
#     [['4', '2'], ['3', '5'], ['1', 'e']]
# resulte 4-2
# 3-5
# 1-e
# Las filas son: [['4', '2'], ['3', '5'], ['1', 'e']]
# las dintancias 2
# las dintancias 2
# las dintancias 2
# las dintancias 4
# las dintancias 6
# las dintancias 6
# 1
# 1
# 1
# 0
#     [['4', '2'], ['e', '3'], ['1', '5']]
# resulte 4-2
# e-3
# 1-5
# Las filas son: [['4', '2'], ['e', '3'], ['1', '5']]
# las dintancias 2
# las dintancias 2
# las dintancias 3
# las dintancias 5
# las dintancias 6
# las dintancias 8
# El expadido es: [Node <4-e 3-2 1-5>, Node <4-2 3-5 1-e>, Node <4-2 e-3 1-5>]
# Node <2-5 3-4 e-1>
# 71
# filas: [['2', '5'], ['3', '4'], ['e', '1']]
# 2
# 0
# las acciones ['3', '1']
# 2
# 0
# 1
# 0
#     [['2', '5'], ['e', '4'], ['3', '1']]
# resulte 2-5
# e-4
# 3-1
# Las filas son: [['2', '5'], ['e', '4'], ['3', '1']]
# las dintancias 3
# las dintancias 4
# las dintancias 5
# las dintancias 5
# las dintancias 8
# las dintancias 10
# 2
# 0
# 2
# 1
#     [['2', '5'], ['3', '4'], ['1', 'e']]
# resulte 2-5
# 3-4
# 1-e
# Las filas son: [['2', '5'], ['3', '4'], ['1', 'e']]
# las dintancias 2
# las dintancias 3
# las dintancias 3
# las dintancias 3
# las dintancias 6
# las dintancias 6
# El expadido es: [Node <2-5 e-4 3-1>, Node <2-5 3-4 1-e>]
# Node <2-5 3-4 1-e>
# 71
# filas: [['2', '5'], ['3', '4'], ['1', 'e']]
# 2
# 1
# las acciones ['4', '1']
# 2
# 1
# 1
# 1
#     [['2', '5'], ['3', 'e'], ['1', '4']]
# resulte 2-5
# 3-e
# 1-4
# Las filas son: [['2', '5'], ['3', 'e'], ['1', '4']]
# las dintancias 2
# las dintancias 3
# las dintancias 3
# las dintancias 4
# las dintancias 7
# las dintancias 8
# 2
# 1
# 2
# 0
#     [['2', '5'], ['3', '4'], ['e', '1']]
# resulte 2-5
# 3-4
# e-1
# Las filas son: [['2', '5'], ['3', '4'], ['e', '1']]
# las dintancias 3
# las dintancias 4
# las dintancias 4
# las dintancias 4
# las dintancias 7
# las dintancias 8
# El expadido es: [Node <2-5 3-e 1-4>, Node <2-5 3-4 e-1>]
# Node <4-2 5-e 3-1>
# 71
# filas: [['4', '2'], ['5', 'e'], ['3', '1']]
# 1
# 1
# las acciones ['2', '1', '5']
# 1
# 1
# 0
# 1
#     [['4', 'e'], ['5', '2'], ['3', '1']]
# resulte 4-e
# 5-2
# 3-1
# Las filas son: [['4', 'e'], ['5', '2'], ['3', '1']]
# las dintancias 3
# las dintancias 4
# las dintancias 5
# las dintancias 7
# las dintancias 8
# las dintancias 10
# 1
# 1
# 2
# 1
#     [['4', '2'], ['5', '1'], ['3', 'e']]
# resulte 4-2
# 5-1
# 3-e
# Las filas son: [['4', '2'], ['5', '1'], ['3', 'e']]
# las dintancias 2
# las dintancias 2
# las dintancias 3
# las dintancias 5
# las dintancias 6
# las dintancias 6
# 1
# 1
# 1
# 0
#     [['4', '2'], ['e', '5'], ['3', '1']]
# resulte 4-2
# e-5
# 3-1
# Las filas son: [['4', '2'], ['e', '5'], ['3', '1']]
# las dintancias 3
# las dintancias 3
# las dintancias 4
# las dintancias 6
# las dintancias 8
# las dintancias 10
# El expadido es: [Node <4-e 5-2 3-1>, Node <4-2 5-1 3-e>, Node <4-2 e-5 3-1>]
# Node <4-2 5-1 3-e>
# 71
# filas: [['4', '2'], ['5', '1'], ['3', 'e']]
# 2
# 1
# las acciones ['1', '3']
# 2
# 1
# 1
# 1
#     [['4', '2'], ['5', 'e'], ['3', '1']]
# resulte 4-2
# 5-e
# 3-1
# Las filas son: [['4', '2'], ['5', 'e'], ['3', '1']]
# las dintancias 3
# las dintancias 3
# las dintancias 4
# las dintancias 6
# las dintancias 7
# las dintancias 8
# 2
# 1
# 2
# 0
#     [['4', '2'], ['5', '1'], ['e', '3']]
# resulte 4-2
# 5-1
# e-3
# Las filas son: [['4', '2'], ['5', '1'], ['e', '3']]
# las dintancias 2
# las dintancias 2
# las dintancias 4
# las dintancias 6
# las dintancias 7
# las dintancias 8
# El expadido es: [Node <4-2 5-e 3-1>, Node <4-2 5-1 e-3>]
# Node <4-2 3-e 1-5>
# 71
# filas: [['4', '2'], ['3', 'e'], ['1', '5']]
# 1
# 1
# las acciones ['2', '5', '3']
# 1
# 1
# 0
# 1
#     [['4', 'e'], ['3', '2'], ['1', '5']]
# resulte 4-e
# 3-2
# 1-5
# Las filas son: [['4', 'e'], ['3', '2'], ['1', '5']]
# las dintancias 2
# las dintancias 3
# las dintancias 3
# las dintancias 5
# las dintancias 6
# las dintancias 8
# 1
# 1
# 2
# 1
#     [['4', '2'], ['3', '5'], ['1', 'e']]
# resulte 4-2
# 3-5
# 1-e
# Las filas son: [['4', '2'], ['3', '5'], ['1', 'e']]
# las dintancias 2
# las dintancias 2
# las dintancias 2
# las dintancias 4
# ...
# 5-1
# 3-e
# Las filas son: [['4', '2'], ['5', '1'], ['3', 'e']]
# las dintancias 2
# las dintancias 2
# las dintancias 3
# las dintancias 5
# las dintancias 6
# las dintancias 6
# 1
# 1
# 1
# 0
#     [['4', '2'], ['e', '5'], ['3', '1']]
# resulte 4-2
# e-5
# 3-1
# Las filas son: [['4', '2'], ['e', '5'], ['3', '1']]
# las dintancias 3
# las dintancias 3
# las dintancias 4
# las dintancias 6
# las dintancias 8
# las dintancias 10
# El expadido es: [Node <4-e 5-2 3-1>, Node <4-2 5-1 3-e>, Node <4-2 e-5 3-1>]
# Node <4-2 5-1 3-e>
# 71
# filas: [['4', '2'], ['5', '1'], ['3', 'e']]
# 2
# 1
# las acciones ['1', '3']
# 2
# 1
# 1
# 1
#     [['4', '2'], ['5', 'e'], ['3', '1']]
# resulte 4-2
# 5-e
# 3-1
# Las filas son: [['4', '2'], ['5', 'e'], ['3', '1']]
# las dintancias 3
# las dintancias 3
# las dintancias 4
# las dintancias 6
# las dintancias 7
# las dintancias 8
# 2
# 1
# 2
# 0
#     [['4', '2'], ['5', '1'], ['e', '3']]
# resulte 4-2
# 5-1
# e-3
# Las filas son: [['4', '2'], ['5', '1'], ['e', '3']]
# las dintancias 2
# las dintancias 2
# las dintancias 4
# las dintancias 6
# las dintancias 7
# las dintancias 8
# El expadido es: [Node <4-2 5-e 3-1>, Node <4-2 5-1 e-3>]
# Node <4-2 3-e 1-5>
# 71
# filas: [['4', '2'], ['3', 'e'], ['1', '5']]
# 1
# 1
# las acciones ['2', '5', '3']
# 1
# 1
# 0
# 1
#     [['4', 'e'], ['3', '2'], ['1', '5']]
# resulte 4-e
# 3-2
# 1-5
# Las filas son: [['4', 'e'], ['3', '2'], ['1', '5']]
# las dintancias 2
# las dintancias 3
# las dintancias 3
# las dintancias 5
# las dintancias 6
# las dintancias 8
# 1
# 1
# 2
# 1
#     [['4', '2'], ['3', '5'], ['1', 'e']]
# resulte 4-2
# 3-5
# 1-e
# Las filas son: [['4', '2'], ['3', '5'], ['1', 'e']]
# las dintancias 2
# las dintancias 2
# las dintancias 2
# las dintancias 4
# las dintancias 6
# las dintancias 6
# 1
# 1
# 1
# 0
#     [['4', '2'], ['e', '3'], ['1', '5']]
# resulte 4-2
# e-3
# 1-5
# Las filas son: [['4', '2'], ['e', '3'], ['1', '5']]
# las dintancias 2
# las dintancias 2
# las dintancias 3
# las dintancias 5
# las dintancias 6
# las dintancias 8
# El expadido es: [Node <4-e 3-2 1-5>, Node <4-2 3-5 1-e>, Node <4-2 e-3 1-5>]
# Node <4-2 3-e 1-5>
# 71
# filas: [['4', '2'], ['3', 'e'], ['1', '5']]
# 1
# 1
# las acciones ['2', '5', '3']
# 1
# 1
# 0
# 1
#     [['4', 'e'], ['3', '2'], ['1', '5']]
# resulte 4-e
# 3-2
# 1-5
# Las filas son: [['4', 'e'], ['3', '2'], ['1', '5']]
# las dintancias 2
# las dintancias 3
# las dintancias 3
# las dintancias 5
# las dintancias 6
# las dintancias 8
# 1
# 1
# 2
# 1
#     [['4', '2'], ['3', '5'], ['1', 'e']]
# resulte 4-2
# 3-5
# 1-e
# Las filas son: [['4', '2'], ['3', '5'], ['1', 'e']]
# las dintancias 2
# las dintancias 2
# las dintancias 2
# las dintancias 4
# las dintancias 6
# las dintancias 6
# 1
# 1
# 1
# 0
#     [['4', '2'], ['e', '3'], ['1', '5']]
# resulte 4-2
# e-3
# 1-5
# Las filas son: [['4', '2'], ['e', '3'], ['1', '5']]
# las dintancias 2
# las dintancias 2
# las dintancias 3
# las dintancias 5
# las dintancias 6
# las dintancias 8
# El expadido es: [Node <4-e 3-2 1-5>, Node <4-2 3-5 1-e>, Node <4-2 e-3 1-5>]
# Node <2-5 3-e 1-4>
# 71
# filas: [['2', '5'], ['3', 'e'], ['1', '4']]
# 1
# 1
# las acciones ['5', '4', '3']
# 1
# 1
# 0
# 1
#     [['2', 'e'], ['3', '5'], ['1', '4']]
# resulte 2-e
# 3-5
# 1-4
# Las filas son: [['2', 'e'], ['3', '5'], ['1', '4']]
# las dintancias 2
# las dintancias 3
# las dintancias 3
# las dintancias 4
# las dintancias 6
# las dintancias 8
# 1
# 1
# 2
# 1
#     [['2', '5'], ['3', '4'], ['1', 'e']]
# resulte 2-5
# 3-4
# 1-e
# Las filas son: [['2', '5'], ['3', '4'], ['1', 'e']]
# las dintancias 2
# las dintancias 3
# las dintancias 3
# las dintancias 3
# las dintancias 6
# las dintancias 6
# 1
# 1
# 1
# 0
#     [['2', '5'], ['e', '3'], ['1', '4']]
# resulte 2-5
# e-3
# 1-4
# Las filas son: [['2', '5'], ['e', '3'], ['1', '4']]
# las dintancias 2
# las dintancias 3
# las dintancias 4
# las dintancias 5
# las dintancias 8
# las dintancias 10
# El expadido es: [Node <2-e 3-5 1-4>, Node <2-5 3-4 1-e>, Node <2-5 e-3 1-4>]
# Node <2-5 3-4 1-e>
# 71
# filas: [['2', '5'], ['3', '4'], ['1', 'e']]
# 2
# 1
# las acciones ['4', '1']
# 2
# 1
# 1
# 1
#     [['2', '5'], ['3', 'e'], ['1', '4']]
# resulte 2-5
# 3-e
# 1-4
# Las filas son: [['2', '5'], ['3', 'e'], ['1', '4']]
# las dintancias 2
# las dintancias 3
# las dintancias 3
# las dintancias 4
# las dintancias 7
# las dintancias 8
# 2
# 1
# 2
# 0
#     [['2', '5'], ['3', '4'], ['e', '1']]
# resulte 2-5
# 3-4
# e-1
# Las filas son: [['2', '5'], ['3', '4'], ['e', '1']]
# las dintancias 3
# las dintancias 4
# las dintancias 4
# las dintancias 4
# las dintancias 7
# las dintancias 8
# El expadido es: [Node <2-5 3-e 1-4>, Node <2-5 3-4 e-1>]
# Node <4-2 5-e 3-1>
# 71
# filas: [['4', '2'], ['5', 'e'], ['3', '1']]
# 1
# 1
# las acciones ['2', '1', '5']
# 1
# 1
# 0
# 1
#     [['4', 'e'], ['5', '2'], ['3', '1']]
# resulte 4-e
# 5-2
# 3-1
# Las filas son: [['4', 'e'], ['5', '2'], ['3', '1']]
# las dintancias 3
# las dintancias 4
# las dintancias 5
# las dintancias 7
# las dintancias 8
# las dintancias 10
# 1
# 1
# 2
# 1
#     [['4', '2'], ['5', '1'], ['3', 'e']]
# resulte 4-2
# 5-1
# 3-e
# Las filas son: [['4', '2'], ['5', '1'], ['3', 'e']]
# las dintancias 2
# las dintancias 2
# las dintancias 3
# las dintancias 5
# las dintancias 6
# las dintancias 6
# 1
# 1
# 1
# 0
#     [['4', '2'], ['e', '5'], ['3', '1']]
# resulte 4-2
# e-5
# 3-1
# Las filas son: [['4', '2'], ['e', '5'], ['3', '1']]
# las dintancias 3
# las dintancias 3
# las dintancias 4
# las dintancias 6
# las dintancias 8
# las dintancias 10
# El expadido es: [Node <4-e 5-2 3-1>, Node <4-2 5-1 3-e>, Node <4-2 e-5 3-1>]
# Node <4-2 5-1 3-e>
# 71
# filas: [['4', '2'], ['5', '1'], ['3', 'e']]
# 2
# 1
# las acciones ['1', '3']
# 2
# 1
# 1
# 1
#     [['4', '2'], ['5', 'e'], ['3', '1']]
# resulte 4-2
# 5-e
# 3-1
# Las filas son: [['4', '2'], ['5', 'e'], ['3', '1']]
# las dintancias 3
# las dintancias 3
# las dintancias 4
# las dintancias 6
# las dintancias 7
# las dintancias 8
# 2
# 1
# 2
# 0
#     [['4', '2'], ['5', '1'], ['e', '3']]
# resulte 4-2
# 5-1
# e-3
# Las filas son: [['4', '2'], ['5', '1'], ['e', '3']]
# las dintancias 2
# las dintancias 2
# las dintancias 4
# las dintancias 6
# las dintancias 7
# las dintancias 8
# El expadido es: [Node <4-2 5-e 3-1>, Node <4-2 5-1 e-3>]
# Node <4-2 3-e 1-5>
# 71
# filas: [['4', '2'], ['3', 'e'], ['1', '5']]
# 1
# 1
# las acciones ['2', '5', '3']
# 1
# 1
# 0
# 1
#     [['4', 'e'], ['3', '2'], ['1', '5']]
# resulte 4-e
# 3-2
# 1-5
# Las filas son: [['4', 'e'], ['3', '2'], ['1', '5']]
# las dintancias 2
# las dintancias 3
# las dintancias 3
# las dintancias 5
# las dintancias 6
# las dintancias 8
# 1
# 1
# 2
# 1
#     [['4', '2'], ['3', '5'], ['1', 'e']]
# resulte 4-2
# 3-5
# 1-e
# Las filas son: [['4', '2'], ['3', '5'], ['1', 'e']]
# las dintancias 2
# las dintancias 2
# las dintancias 2
# las dintancias 4
# las dintancias 6
# las dintancias 6
# 1
# 1
# 1
# 0
#     [['4', '2'], ['e', '3'], ['1', '5']]
# resulte 4-2
# e-3
# 1-5
# Las filas son: [['4', '2'], ['e', '3'], ['1', '5']]
# las dintancias 2
# las dintancias 2
# las dintancias 3
# las dintancias 5
# las dintancias 6
# las dintancias 8
# El expadido es: [Node <4-e 3-2 1-5>, Node <4-2 3-5 1-e>, Node <4-2 e-3 1-5>]
# Node <2-5 3-e 1-4>
# 71
# filas: [['2', '5'], ['3', 'e'], ['1', '4']]
# 1
# 1
# las acciones ['5', '4', '3']
# 1
# 1
# 0
# 1
#     [['2', 'e'], ['3', '5'], ['1', '4']]
# resulte 2-e
# 3-5
# 1-4
# Las filas son: [['2', 'e'], ['3', '5'], ['1', '4']]
# las dintancias 2
# las dintancias 3
# las dintancias 3
# las dintancias 4
# las dintancias 6
# las dintancias 8
# 1
# 1
# 2
# 1
#     [['2', '5'], ['3', '4'], ['1', 'e']]
# resulte 2-5
# 3-4
# 1-e
# Las filas son: [['2', '5'], ['3', '4'], ['1', 'e']]
# las dintancias 2
# las dintancias 3
# las dintancias 3
# las dintancias 3
# las dintancias 6
# las dintancias 6
# 1
# 1
# 1
# 0
#     [['2', '5'], ['e', '3'], ['1', '4']]
# resulte 2-5
# e-3
# 1-4
# Las filas son: [['2', '5'], ['e', '3'], ['1', '4']]
# las dintancias 2
# las dintancias 3
# las dintancias 4
# las dintancias 5
# las dintancias 8
# las dintancias 10
# El expadido es: [Node <2-e 3-5 1-4>, Node <2-5 3-4 1-e>, Node <2-5 e-3 1-4>]
# Node <2-5 3-4 1-e>
# 71
# filas: [['2', '5'], ['3', '4'], ['1', 'e']]
# 2
# 1
# las acciones ['4', '1']
# 2
# 1
# 1
# 1
#     [['2', '5'], ['3', 'e'], ['1', '4']]
# resulte 2-5
# 3-e
# 1-4
# Las filas son: [['2', '5'], ['3', 'e'], ['1', '4']]
# las dintancias 2
# las dintancias 3
# las dintancias 3
# las dintancias 4
# las dintancias 7
# las dintancias 8
# 2
# 1
# 2
# 0
#     [['2', '5'], ['3', '4'], ['e', '1']]
# resulte 2-5
# 3-4
# e-1
# Las filas son: [['2', '5'], ['3', '4'], ['e', '1']]
# las dintancias 3
# las dintancias 4
# las dintancias 4
# las dintancias 4
# las dintancias 7
# las dintancias 8
# El expadido es: [Node <2-5 3-e 1-4>, Node <2-5 3-4 e-1>]
# Node <e-2 1-5 4-3>
# 72
# filas: [['e', '2'], ['1', '5'], ['4', '3']]
# 0
# 0
# las acciones ['1', '2']
# 0
# 0
# 1
# 0
#     [['1', '2'], ['e', '5'], ['4', '3']]
# resulte 1-2
# e-5
# 4-3
# Las filas son: [['1', '2'], ['e', '5'], ['4', '3']]
# las dintancias 0
# las dintancias 0
# las dintancias 2
# las dintancias 4
# las dintancias 6
# las dintancias 8
# 0
# 0
# 0
# 1
#     [['2', 'e'], ['1', '5'], ['4', '3']]
# resulte 2-e
# 1-5
# 4-3
# Las filas son: [['2', 'e'], ['1', '5'], ['4', '3']]
# las dintancias 1
# las dintancias 2
# las dintancias 4
# las dintancias 6
# las dintancias 8
# las dintancias 10
# El expadido es: [Node <1-2 e-5 4-3>, Node <2-e 1-5 4-3>]
# Node <1-2 e-5 4-3>
# 73
# filas: [['1', '2'], ['e', '5'], ['4', '3']]
# 1
# 0
# las acciones ['1', '4', '5']
# 1
# 0
# 0
# 0
#     [['e', '2'], ['1', '5'], ['4', '3']]
# resulte e-2
# 1-5
# 4-3
# Las filas son: [['e', '2'], ['1', '5'], ['4', '3']]
# las dintancias 1
# las dintancias 1
# las dintancias 3
# las dintancias 5
# las dintancias 7
# las dintancias 10
# 1
# 0
# 2
# 0
#     [['1', '2'], ['4', '5'], ['e', '3']]
# resulte 1-2
# 4-5
# e-3
# Las filas son: [['1', '2'], ['4', '5'], ['e', '3']]
# las dintancias 0
# las dintancias 0
# las dintancias 2
# las dintancias 3
# las dintancias 5
# las dintancias 6
# 1
# 0
# 1
# 1
#     [['1', '2'], ['5', 'e'], ['4', '3']]
# resulte 1-2
# 5-e
# 4-3
# Las filas son: [['1', '2'], ['5', 'e'], ['4', '3']]
# las dintancias 0
# las dintancias 0
# las dintancias 2
# las dintancias 4
# las dintancias 5
# las dintancias 6
# El expadido es: [Node <e-2 1-5 4-3>, Node <1-2 4-5 e-3>, Node <1-2 5-e 4-3>]
# Node <1-2 4-5 e-3>
# 74
# filas: [['1', '2'], ['4', '5'], ['e', '3']]
# 2
# 0
# las acciones ['4', '3']
# 2
# 0
# 1
# 0
#     [['1', '2'], ['e', '5'], ['4', '3']]
# resulte 1-2
# e-5
# 4-3
# Las filas son: [['1', '2'], ['e', '5'], ['4', '3']]
# las dintancias 0
# las dintancias 0
# las dintancias 2
# las dintancias 4
# las dintancias 6
# las dintancias 8
# 2
# 0
# 2
# 1
#     [['1', '2'], ['4', '5'], ['3', 'e']]
# resulte 1-2
# 4-5
# 3-e
# Las filas son: [['1', '2'], ['4', '5'], ['3', 'e']]
# las dintancias 0
# las dintancias 0
# las dintancias 1
# las dintancias 2
# las dintancias 4
# las dintancias 4
# El expadido es: [Node <1-2 e-5 4-3>, Node <1-2 4-5 3-e>]
# Node <1-2 4-5 3-e>
# 75
# filas: [['1', '2'], ['4', '5'], ['3', 'e']]
# 2
# 1
# las acciones ['5', '3']
# 2
# 1
# 1
# 1
#     [['1', '2'], ['4', 'e'], ['3', '5']]
# resulte 1-2
# 4-e
# 3-5
# Las filas son: [['1', '2'], ['4', 'e'], ['3', '5']]
# las dintancias 0
# las dintancias 0
# las dintancias 1
# las dintancias 2
# las dintancias 3
# las dintancias 4
# 2
# 1
# 2
# 0
#     [['1', '2'], ['4', '5'], ['e', '3']]
# resulte 1-2
# 4-5
# e-3
# Las filas son: [['1', '2'], ['4', '5'], ['e', '3']]
# las dintancias 0
# las dintancias 0
# las dintancias 2
# las dintancias 3
# las dintancias 5
# las dintancias 6
# El expadido es: [Node <1-2 4-e 3-5>, Node <1-2 4-5 e-3>]
# Node <1-2 5-e 4-3>
# 76
# filas: [['1', '2'], ['5', 'e'], ['4', '3']]
# 1
# 1
# las acciones ['2', '3', '5']
# 1
# 1
# 0
# 1
#     [['1', 'e'], ['5', '2'], ['4', '3']]
# resulte 1-e
# 5-2
# 4-3
# Las filas son: [['1', 'e'], ['5', '2'], ['4', '3']]
# las dintancias 0
# las dintancias 1
# las dintancias 3
# las dintancias 5
# las dintancias 6
# las dintancias 8
# 1
# 1
# 2
# 1
#     [['1', '2'], ['5', '3'], ['4', 'e']]
# resulte 1-2
# 5-3
# 4-e
# Las filas son: [['1', '2'], ['5', '3'], ['4', 'e']]
# las dintancias 0
# las dintancias 0
# las dintancias 1
# las dintancias 3
# las dintancias 4
# las dintancias 4
# 1
# 1
# 1
# 0
#     [['1', '2'], ['e', '5'], ['4', '3']]
# resulte 1-2
# e-5
# 4-3
# Las filas son: [['1', '2'], ['e', '5'], ['4', '3']]
# las dintancias 0
# las dintancias 0
# las dintancias 2
# las dintancias 4
# las dintancias 6
# las dintancias 8
# El expadido es: [Node <1-e 5-2 4-3>, Node <1-2 5-3 4-e>, Node <1-2 e-5 4-3>]
# Node <1-2 5-3 4-e>
# 77
# filas: [['1', '2'], ['5', '3'], ['4', 'e']]
# 2
# 1
# las acciones ['3', '4']
# 2
# 1
# 1
# 1
#     [['1', '2'], ['5', 'e'], ['4', '3']]
# resulte 1-2
# 5-e
# 4-3
# Las filas son: [['1', '2'], ['5', 'e'], ['4', '3']]
# las dintancias 0
# las dintancias 0
# las dintancias 2
# las dintancias 4
# las dintancias 5
# las dintancias 6
# 2
# 1
# 2
# 0
#     [['1', '2'], ['5', '3'], ['e', '4']]
# resulte 1-2
# 5-3
# e-4
# Las filas son: [['1', '2'], ['5', '3'], ['e', '4']]
# las dintancias 0
# las dintancias 0
# las dintancias 1
# las dintancias 2
# las dintancias 3
# las dintancias 4
# El expadido es: [Node <1-2 5-e 4-3>, Node <1-2 5-3 e-4>]
# Node <1-2 4-e 3-5>
# 78
# filas: [['1', '2'], ['4', 'e'], ['3', '5']]
# 1
# 1
# las acciones ['2', '5', '4']
# 1
# 1
# 0
# 1
#     [['1', 'e'], ['4', '2'], ['3', '5']]
# resulte 1-e
# 4-2
# 3-5
# Las filas son: [['1', 'e'], ['4', '2'], ['3', '5']]
# las dintancias 0
# las dintancias 1
# las dintancias 2
# las dintancias 3
# las dintancias 4
# las dintancias 6
# 1
# 1
# 2
# 1
#     [['1', '2'], ['4', '5'], ['3', 'e']]
# resulte 1-2
# 4-5
# 3-e
# Las filas son: [['1', '2'], ['4', '5'], ['3', 'e']]
# las dintancias 0
# las dintancias 0
# las dintancias 1
# las dintancias 2
# las dintancias 4
# las dintancias 4
# 1
# 1
# 1
# 0
#     [['1', '2'], ['e', '4'], ['3', '5']]
# resulte 1-2
# e-4
# 3-5
# Las filas son: [['1', '2'], ['e', '4'], ['3', '5']]
# las dintancias 0
# las dintancias 0
# las dintancias 1
# las dintancias 1
# las dintancias 2
# las dintancias 4
# El expadido es: [Node <1-e 4-2 3-5>, Node <1-2 4-5 3-e>, Node <1-2 e-4 3-5>]
# Node <1-2 5-3 e-4>
# 79
# filas: [['1', '2'], ['5', '3'], ['e', '4']]
# 2
# 0
# las acciones ['5', '4']
# 2
# 0
# 1
# 0
#     [['1', '2'], ['e', '3'], ['5', '4']]
# resulte 1-2
# e-3
# 5-4
# Las filas son: [['1', '2'], ['e', '3'], ['5', '4']]
# las dintancias 0
# las dintancias 0
# las dintancias 1
# las dintancias 2
# las dintancias 2
# las dintancias 4
# 2
# 0
# 2
# 1
#     [['1', '2'], ['5', '3'], ['4', 'e']]
# resulte 1-2
# 5-3
# 4-e
# Las filas son: [['1', '2'], ['5', '3'], ['4', 'e']]
# las dintancias 0
# las dintancias 0
# las dintancias 1
# las dintancias 3
# las dintancias 4
# las dintancias 4
# El expadido es: [Node <1-2 e-3 5-4>, Node <1-2 5-3 4-e>]
# Node <1-2 4-5 3-e>
# 79
# filas: [['1', '2'], ['4', '5'], ['3', 'e']]
# 2
# 1
# las acciones ['5', '3']
# 2
# 1
# 1
# 1
#     [['1', '2'], ['4', 'e'], ['3', '5']]
# resulte 1-2
# 4-e
# 3-5
# Las filas son: [['1', '2'], ['4', 'e'], ['3', '5']]
# las dintancias 0
# las dintancias 0
# las dintancias 1
# las dintancias 2
# las dintancias 3
# las dintancias 4
# 2
# 1
# 2
# 0
#     [['1', '2'], ['4', '5'], ['e', '3']]
# resulte 1-2
# 4-5
# e-3
# Las filas son: [['1', '2'], ['4', '5'], ['e', '3']]
# las dintancias 0
# las dintancias 0
# las dintancias 2
# las dintancias 3
# las dintancias 5
# las dintancias 6
# El expadido es: [Node <1-2 4-e 3-5>, Node <1-2 4-5 e-3>]
# Node <1-2 e-4 3-5>
# 80
# filas: [['1', '2'], ['e', '4'], ['3', '5']]
# 1
# 0
# las acciones ['1', '3', '4']
# 1
# 0
# 0
# 0
#     [['e', '2'], ['1', '4'], ['3', '5']]
# resulte e-2
# 1-4
# 3-5
# Las filas son: [['e', '2'], ['1', '4'], ['3', '5']]
# las dintancias 1
# las dintancias 1
# las dintancias 2
# las dintancias 2
# las dintancias 3
# las dintancias 6
# 1
# 0
# 2
# 0
#     [['1', '2'], ['3', '4'], ['e', '5']]
# resulte 1-2
# 3-4
# e-5
# Las filas son: [['1', '2'], ['3', '4'], ['e', '5']]
# las dintancias 0
# las dintancias 0
# las dintancias 0
# las dintancias 0
# las dintancias 1
# las dintancias 2
# 1
# 0
# 1
# 1
#     [['1', '2'], ['4', 'e'], ['3', '5']]
# resulte 1-2
# 4-e
# 3-5
# Las filas son: [['1', '2'], ['4', 'e'], ['3', '5']]
# las dintancias 0
# las dintancias 0
# las dintancias 1
# las dintancias 2
# las dintancias 3
# las dintancias 4
# El expadido es: [Node <e-2 1-4 3-5>, Node <1-2 3-4 e-5>, Node <1-2 4-e 3-5>]
# Node <1-2 3-4 e-5>
# 81
# filas: [['1', '2'], ['3', '4'], ['e', '5']]
# 2
# 0
# las acciones ['3', '5']
# 2
# 0
# 1
# 0
#     [['1', '2'], ['e', '4'], ['3', '5']]
# resulte 1-2
# e-4
# 3-5
# Las filas son: [['1', '2'], ['e', '4'], ['3', '5']]
# las dintancias 0
# las dintancias 0
# las dintancias 1
# las dintancias 1
# las dintancias 2
# las dintancias 4
# 2
# 0
# 2
# 1
#     [['1', '2'], ['3', '4'], ['5', 'e']]
# resulte 1-2
# 3-4
# 5-e
# Las filas son: [['1', '2'], ['3', '4'], ['5', 'e']]
# las dintancias 0
# las dintancias 0
# las dintancias 0
# las dintancias 0
# las dintancias 0
# las dintancias 0
# El expadido es: [Node <1-2 e-4 3-5>, Node <1-2 3-4 5-e>]
# Node <1-2 3-4 5-e>
# 1-2
# 3-4
# 5-e
# Node <1-2 3-4 5-e>
# Mueve el numero None
# 2-e
# 4-5
# 3-1
# Mueve el numero 5
# 2-5
# 4-e
# 3-1
# Mueve el numero 1
# 2-5
# 4-1
# 3-e
# Mueve el numero 3
# 2-5
# 4-1
# e-3
# Mueve el numero 4
# 2-5
# e-1
# 4-3
# Mueve el numero 1
# 2-5
# 1-e
# 4-3
# Mueve el numero 5
# 2-e
# 1-5
# 4-3
# Mueve el numero 2
# e-2
# 1-5
# 4-3
# Mueve el numero 1
# 1-2
# e-5
# 4-3
# Mueve el numero 4
# 1-2
# 4-5
# e-3
# Mueve el numero 3
# 1-2
# 4-5
# 3-e
# Mueve el numero 5
# 1-2
# 4-e
# 3-5
# Mueve el numero 4
# 1-2
# e-4
# 3-5
# Mueve el numero 3
# 1-2
# 3-4
# e-5
# Mueve el numero 5
# 1-2
# 3-4
# 5-e
